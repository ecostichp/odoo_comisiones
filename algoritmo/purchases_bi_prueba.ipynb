# %%
from algoritmo_ventas_mes import ventas_mes_func
from descriptions import descrip_sales_users_df, descrip_product_df

import pandas as pd
from pathlib import Path

pd.options.display.float_format = '{:,.2f}'.format

# %%
ventas_enero = ventas_mes_func(1)
ventas_febrero = ventas_mes_func(2)
ventas_marzo = ventas_mes_func(3)
ventas_abril = ventas_mes_func(4)
ventas_mayo = ventas_mes_func(5)

# %%
df = ventas_mayo
mes = 5

# %%
ventas = df[['salesperson_id', 'product_id','quantity', 'price_subtotal']].merge(descrip_sales_users_df, how='left', left_on='salesperson_id', right_on='id')
compras = ventas.merge(descrip_product_df, how='left', on='product_id')

# %%
compras
# Out:
#        salesperson_id  product_id  quantity  price_subtotal     id  \
# 0                 224       28737     15.00        1,243.05 224.00
# 1                 224       28738     15.00          211.20 224.00
# 2                 212       12938      1.00          262.44 212.00
# 3                 212        8099     20.00          125.63 212.00
# 4                 212       10710      1.00           63.62 212.00
# ...               ...         ...       ...             ...    ...
# 10328             214        8508      3.00           46.23 214.00
# 10329             214        9768      1.00           44.44 214.00
# 10330             214       28835      1.00           43.37 214.00
# 10331             214       28928      1.00           44.44 214.00
# 10332             227       12421      1.00          214.60 227.00
#
#                                    name active  sale_team_id  \
# 0                 Leticia Terán Salinas   True             5
# 1                 Leticia Terán Salinas   True             5
# 2                  Reyna Arriaga Flores   True             5
# 3                  Reyna Arriaga Flores   True             5
# 4                  Reyna Arriaga Flores   True             5
# ...                                 ...    ...           ...
# 10328  Sandra Jaqueline Hernandez Rojas   True             6
# 10329  Sandra Jaqueline Hernandez Rojas   True             6
# 10330  Sandra Jaqueline Hernandez Rojas   True             6
# 10331  Sandra Jaqueline Hernandez Rojas   True             6
# 10332         Patricia Flores Pantaleón   True             6
#
#       sale_team_description business_model warehouse  \
# 0                    A1 CSL           Piso        A1
# 1                    A1 CSL           Piso        A1
# 2                    A1 CSL           Piso        A1
# 3                    A1 CSL           Piso        A1
# 4                    A1 CSL           Piso        A1
# ...                     ...            ...       ...
# 10328                A2 SJC           Piso        A2
# 10329                A2 SJC           Piso        A2
# 10330                A2 SJC           Piso        A2
# 10331                A2 SJC           Piso        A2
# 10332                A2 SJC           Piso        A2
#
#                                        prod_descripción prod_código prod_línea
# 0                  Tijera P/Holatero Urrea 303r *20450*       20450      000CE
# 1         Disco 4.5 Corte Fino 115 mm NINJA 4.5 *20449*       20449      000CE
# 2          Broca Forstner MK D-50675 1-3/8x3/8" *11272*       11272      0MAKA
# 3             Lija Dis. C/Vel. 5" G-100 Fand C#8 *8454*        8454      00FAN
# 4                   Aguarras Sayer D-0102 (1Lt) *13142*       13142      0SAYL
# ...                                                 ...         ...        ...
# 10328              Caja Plastico CCH-2X4P 45005 *45821*       45821      00TRU
# 10329    Placa Interruptor-Contacto Trup #48489 *48489*       48489      00TRU
# 10330          Perfil 107 C-14 C-150 (LM-H1515) *20198*       20198      000CE
# 10331                                               NaN         NaN        NaN
# 10332  Clavo P/Clav Neum 1 3/4" C-18 Trup#18268 *18268*       18268      00TRU
#
# [10333 rows x 14 columns]

# %% [markdown]
# ## Algo de <span style="color: steelblue">BI</span>

# %%
compras_linea = compras.groupby(['prod_línea', 'prod_código']).agg({'quantity':['count', 'sum', 'max', 'min', 'mean'], 'prod_descripción':['first']})
compras_linea
# Out:
#                        quantity                            \
#                           count    sum    max   min  mean
# prod_línea prod_código
# 0          13390              1  10.00  10.00 10.00 10.00
#            13510              1  20.00  20.00 20.00 20.00
#            15068              1   1.00   1.00  1.00  1.00
#            1536               1  50.00  50.00 50.00 50.00
#            1644               1   3.00   3.00  3.00  3.00
# ...                         ...    ...    ...   ...   ...
# 8          33221              8 137.80  40.00  2.80 17.23
#            75133              9 229.00 100.00  4.00 25.44
# 9          13738              1  10.00  10.00 10.00 10.00
#            14544              1   8.00   8.00  8.00  8.00
#            2234               1  24.00  24.00 24.00 24.00
#
#                                                          prod_descripción
#                                                                     first
# prod_línea prod_código
# 0          13390                             Chilillo p/Mad.10*4" *13390*
#            13510                 Grapa P/Espejo Pza. N0.2 C#163-B *13510*
#            15068                Balero Amana #6000 (Jgo) p/#49340 *15068*
#            1536                             Chilillo P/Mad.8*1 1/4 *1536*
#            1644                              Clavo P/Madera 3" S/C *1644*
# ...                                                                   ...
# 8          33221              Cubrecanto 22mm Chapa Maple CA (1m) *33221*
#            75133             Cubrecanto 50mm Chapa Parota CA (1m) *75133*
# 9          13738           Cierra Puerta Hafele Cafe  #931.77.031 *13738*
#            14544          Cierra Puerta Hafele Oculto #931.77.029 *14544*
#            2234         Riel D/Extenc. Completa Cierre Suave 12" 300mm...
#
# [2708 rows x 6 columns]

# %%
compras_linea_sale_team = compras.groupby(['prod_línea', 'sale_team_description', 'prod_código']).agg({'quantity':['count', 'sum', 'max', 'min', 'mean'], 'prod_descripción':['first']})
compras_linea_sale_team
# Out:
#                                              quantity                       \
#                                                 count    sum    max    min
# prod_línea sale_team_description prod_código
# 0          A1 CSL                13510              1  20.00  20.00  20.00
#                                  15068              1   1.00   1.00   1.00
#                                  1536               1  50.00  50.00  50.00
#                                  2109               1   1.00   1.00   1.00
#                                  3843               1 100.00 100.00 100.00
# ...                                               ...    ...    ...    ...
# 8          A2 SJC                75133              4  75.00  40.00   5.00
#            CE A1                 13984              1 100.00 100.00 100.00
# 9          CE A1                 13738              1  10.00  10.00  10.00
#                                  14544              1   8.00   8.00   8.00
#                                  2234               1  24.00  24.00  24.00
#
#                                                      \
#                                                mean
# prod_línea sale_team_description prod_código
# 0          A1 CSL                13510        20.00
#                                  15068         1.00
#                                  1536         50.00
#                                  2109          1.00
#                                  3843        100.00
# ...                                             ...
# 8          A2 SJC                75133        18.75
#            CE A1                 13984       100.00
# 9          CE A1                 13738        10.00
#                                  14544         8.00
#                                  2234         24.00
#
#                                                                                prod_descripción
#                                                                                           first
# prod_línea sale_team_description prod_código
# 0          A1 CSL                13510                 Grapa P/Espejo Pza. N0.2 C#163-B *13510*
#                                  15068                Balero Amana #6000 (Jgo) p/#49340 *15068*
#                                  1536                             Chilillo P/Mad.8*1 1/4 *1536*
#                                  2109                      Equipo D/Mesa P/Dw614 Dw-6900 *2109*
#                                  3843                      Pija C/Hexagonal 1/4*1" (#20) *3843*
# ...                                                                                         ...
# 8          A2 SJC                75133             Cubrecanto 50mm Chapa Parota CA (1m) *75133*
#            CE A1                 13984             Cubrecanto 22mm Chapa Parota CA (1m) *13984*
# 9          CE A1                 13738           Cierra Puerta Hafele Cafe  #931.77.031 *13738*
#                                  14544          Cierra Puerta Hafele Oculto #931.77.029 *14544*
#                                  2234         Riel D/Extenc. Completa Cierre Suave 12" 300mm...
#
# [4002 rows x 6 columns]

# %%
compras_linea_vendedora = compras.groupby(['prod_línea', 'name', 'prod_código']).agg({'quantity':['count', 'sum', 'max', 'min', 'mean'], 'prod_descripción':['first']})
compras_linea_vendedora
# Out:
#                                                             quantity        \
#                                                                count   sum
# prod_línea name                                 prod_código
# 0          Gladiz Melisa Galvez Espinoza        13510              1 20.00
#                                                 2109               1  1.00
#                                                 5010               1  1.00
#                                                 6910               1  1.00
#                                                 85265              3  4.00
# ...                                                              ...   ...
# 8          Yolanda Alejandra Rodriguez González 33221              1  2.80
#                                                 75133              1 10.00
# 9          Irma Carvajal Flores                 14544              1  8.00
#                                                 2234               1 24.00
#            Mayra Angelica Parada Manjarrez      13738              1 10.00
#
#                                                                                \
#                                                               max   min  mean
# prod_línea name                                 prod_código
# 0          Gladiz Melisa Galvez Espinoza        13510       20.00 20.00 20.00
#                                                 2109         1.00  1.00  1.00
#                                                 5010         1.00  1.00  1.00
#                                                 6910         1.00  1.00  1.00
#                                                 85265        2.00  1.00  1.33
# ...                                                           ...   ...   ...
# 8          Yolanda Alejandra Rodriguez González 33221        2.80  2.80  2.80
#                                                 75133       10.00 10.00 10.00
# 9          Irma Carvajal Flores                 14544        8.00  8.00  8.00
#                                                 2234        24.00 24.00 24.00
#            Mayra Angelica Parada Manjarrez      13738       10.00 10.00 10.00
#
#                                                                                               prod_descripción
#                                                                                                          first
# prod_línea name                                 prod_código
# 0          Gladiz Melisa Galvez Espinoza        13510                 Grapa P/Espejo Pza. N0.2 C#163-B *13510*
#                                                 2109                      Equipo D/Mesa P/Dw614 Dw-6900 *2109*
#                                                 5010               Llave P/Broquero 10V(D-1533-03) 1/2" *5010*
#                                                 6910             Llave P/Broquero Tipo "T" 1/2 (Jacobs) *6910*
#                                                 85265                          Lapiz P/Carpintero (Pz) *85265*
# ...                                                                                                        ...
# 8          Yolanda Alejandra Rodriguez González 33221              Cubrecanto 22mm Chapa Maple CA (1m) *33221*
#                                                 75133             Cubrecanto 50mm Chapa Parota CA (1m) *75133*
# 9          Irma Carvajal Flores                 14544          Cierra Puerta Hafele Oculto #931.77.029 *14544*
#                                                 2234         Riel D/Extenc. Completa Cierre Suave 12" 300mm...
#            Mayra Angelica Parada Manjarrez      13738           Cierra Puerta Hafele Cafe  #931.77.031 *13738*
#
# [6094 rows x 6 columns]

# %%
compras_almacen = compras.groupby(['warehouse', 'prod_línea', 'prod_código']).agg({'quantity':['count', 'sum', 'max', 'min', 'mean'], 'prod_descripción':['first']})
compras_almacen
# Out:
#                                  quantity                            \
#                                     count    sum    max   min  mean
# warehouse prod_línea prod_código
# A1        0          13510              1  20.00  20.00 20.00 20.00
#                      15068              1   1.00   1.00  1.00  1.00
#                      1536               1  50.00  50.00 50.00 50.00
#                      1644               1   3.00   3.00  3.00  3.00
#                      2109               1   1.00   1.00  1.00  1.00
# ...                                   ...    ...    ...   ...   ...
# A2        8          20247              6 122.00  50.00 10.00 20.33
#                      2240               2  28.00  27.00  1.00 14.00
#                      2253               3 128.00 100.00  8.00 42.67
#                      33221              3  46.80  40.00  2.80 15.60
#                      75133              4  75.00  40.00  5.00 18.75
#
#                                                                prod_descripción
#                                                                           first
# warehouse prod_línea prod_código
# A1        0          13510             Grapa P/Espejo Pza. N0.2 C#163-B *13510*
#                      15068            Balero Amana #6000 (Jgo) p/#49340 *15068*
#                      1536                         Chilillo P/Mad.8*1 1/4 *1536*
#                      1644                          Clavo P/Madera 3" S/C *1644*
#                      2109                  Equipo D/Mesa P/Dw614 Dw-6900 *2109*
# ...                                                                         ...
# A2        8          20247           Cubrecanto 22mm Chapa Pino (1m) CA *20247*
#                      2240         Cubrecanto 22mm Melamina Negro CA (1m) *2240*
#                      2253         Cubrecanto 22mm Chapa Enc Rojo CA (1m) *2253*
#                      33221          Cubrecanto 22mm Chapa Maple CA (1m) *33221*
#                      75133         Cubrecanto 50mm Chapa Parota CA (1m) *75133*
#
# [3584 rows x 6 columns]

# %%
compras_modelo_negocios = compras.groupby(['business_model', 'prod_línea', 'prod_código']).agg({'quantity':['count', 'sum', 'max', 'min', 'mean'], 'prod_descripción':['first']})
compras_modelo_negocios
# Out:
#                                       quantity                            \
#                                          count    sum    max   min  mean
# business_model prod_línea prod_código
# CE             0          1644               1   3.00   3.00  3.00  3.00
#                000CE      101001             3  55.00  30.00 10.00 18.33
#                           10129              1   8.00   8.00  8.00  8.00
#                           104100             1   1.00   1.00  1.00  1.00
#                           10992              2   4.00   3.00  1.00  2.00
# ...                                        ...    ...    ...   ...   ...
# Piso           8          2240               2  28.00  27.00  1.00 14.00
#                           2253               6 229.00 100.00  8.00 38.17
#                           22544              3  17.00  10.00  1.00  5.67
#                           33221              7 129.80  40.00  2.80 18.54
#                           75133              7 210.00 100.00  5.00 30.00
#
#                                                                         prod_descripción
#                                                                                    first
# business_model prod_línea prod_código
# CE             0          1644                              Clavo P/Madera 3" S/C *1644*
#                000CE      101001                   Pintura Kem-Tone Mate 711 SW *101001*
#                           10129        Sil.Resistol No Mas Clavos (353gr) Fuerte y Fa...
#                           104100          Pinza Recta 10" #10410 Klein Tools CE *104100*
#                           10992           Papel Verde 18*60 YDS TOT12218 Trimaco *10992*
# ...                                                                                  ...
# Piso           8          2240             Cubrecanto 22mm Melamina Negro CA (1m) *2240*
#                           2253             Cubrecanto 22mm Chapa Enc Rojo CA (1m) *2253*
#                           22544          Cubrecanto 290mm Chapa Enc Rojo SA (1m) *22544*
#                           33221              Cubrecanto 22mm Chapa Maple CA (1m) *33221*
#                           75133             Cubrecanto 50mm Chapa Parota CA (1m) *75133*
#
# [3083 rows x 6 columns]

# %%
compras_folio_ventas = compras.groupby(['sale_team_description', 'prod_línea', 'prod_código']).agg({'quantity':['count', 'sum', 'max', 'min', 'mean'], 'prod_descripción':['first']})
compras_folio_ventas
# Out:
#                                              quantity                       \
#                                                 count    sum    max    min
# sale_team_description prod_línea prod_código
# A1 CSL                0          13510              1  20.00  20.00  20.00
#                                  15068              1   1.00   1.00   1.00
#                                  1536               1  50.00  50.00  50.00
#                                  2109               1   1.00   1.00   1.00
#                                  3843               1 100.00 100.00 100.00
# ...                                               ...    ...    ...    ...
# CE A2                 45         70061              1   3.00   3.00   3.00
#                                  8498               2   7.00   5.00   2.00
#                                  8971               1   1.00   1.00   1.00
#                                  9911               1   3.00   3.00   3.00
#                       72         25770              1   6.00   6.00   6.00
#
#                                                      \
#                                                mean
# sale_team_description prod_línea prod_código
# A1 CSL                0          13510        20.00
#                                  15068         1.00
#                                  1536         50.00
#                                  2109          1.00
#                                  3843        100.00
# ...                                             ...
# CE A2                 45         70061         3.00
#                                  8498          3.50
#                                  8971          1.00
#                                  9911          3.00
#                       72         25770         6.00
#
#                                                                               prod_descripción
#                                                                                          first
# sale_team_description prod_línea prod_código
# A1 CSL                0          13510                Grapa P/Espejo Pza. N0.2 C#163-B *13510*
#                                  15068               Balero Amana #6000 (Jgo) p/#49340 *15068*
#                                  1536                            Chilillo P/Mad.8*1 1/4 *1536*
#                                  2109                     Equipo D/Mesa P/Dw614 Dw-6900 *2109*
#                                  3843                     Pija C/Hexagonal 1/4*1" (#20) *3843*
# ...                                                                                        ...
# CE A2                 45         70061        Cartucho P/ Mascarilla Mod 6001 3M (2Pz) *70061*
#                                  8498                 Flexometro 5m 3/4" Cadena WDA5020 *8498*
#                                  8971          Flexometro 5m 3/4" Cadena MGA5020 V Dobl *8971*
#                                  9911                       Mascarilla 3M MOD.6200 (Pz) *9911*
#                       72         25770              Pasador 620-40 NS JAKO #PJ620-40NS *25770*
#
# [4002 rows x 6 columns]

# %%
compras_vendedora = compras.groupby(['name', 'prod_línea', 'prod_código']).agg({'quantity':['count', 'sum', 'max', 'min', 'mean'], 'prod_descripción':['first']})
compras_vendedora
# Out:
#                                                             quantity         \
#                                                                count    sum
# name                                 prod_línea prod_código
# Brenda Luz Acosta Lopez              000CE      1362               1  60.00
#                                                 14342              1   3.00
#                                                 14391              1   5.00
#                                                 14392              1   5.00
#                                                 14399              1  50.00
# ...                                                              ...    ...
# Yolanda Alejandra Rodriguez González 8          13984              2  34.00
#                                                 20247              3  85.00
#                                                 2253               1 100.00
#                                                 33221              1   2.80
#                                                 75133              1  10.00
#
#                                                                            \
#                                                                max    min
# name                                 prod_línea prod_código
# Brenda Luz Acosta Lopez              000CE      1362         60.00  60.00
#                                                 14342         3.00   3.00
#                                                 14391         5.00   5.00
#                                                 14392         5.00   5.00
#                                                 14399        50.00  50.00
# ...                                                            ...    ...
# Yolanda Alejandra Rodriguez González 8          13984        30.00   4.00
#                                                 20247        50.00  15.00
#                                                 2253        100.00 100.00
#                                                 33221         2.80   2.80
#                                                 75133        10.00  10.00
#
#                                                                     \
#                                                               mean
# name                                 prod_línea prod_código
# Brenda Luz Acosta Lopez              000CE      1362         60.00
#                                                 14342         3.00
#                                                 14391         5.00
#                                                 14392         5.00
#                                                 14399        50.00
# ...                                                            ...
# Yolanda Alejandra Rodriguez González 8          13984        17.00
#                                                 20247        28.33
#                                                 2253        100.00
#                                                 33221         2.80
#                                                 75133        10.00
#
#                                                                                             prod_descripción
#                                                                                                        first
# name                                 prod_línea prod_código
# Brenda Luz Acosta Lopez              000CE      1362         Rodillo microfibra 3/8 x 6"maneral/felpa *1362*
#                                                 14342                   Navaja Retractil Stanley 5pz *14342*
#                                                 14391          Soldadura 6013 3/32" Kilo Trup #14360 *14391*
#                                                 14392                        Soldadura 6011 1/8 Kilo *14392*
#                                                 14399              Canaleta D/Carga 1-5/8x10 Cal- 22 *14399*
# ...                                                                                                      ...
# Yolanda Alejandra Rodriguez González 8          13984           Cubrecanto 22mm Chapa Parota CA (1m) *13984*
#                                                 20247             Cubrecanto 22mm Chapa Pino (1m) CA *20247*
#                                                 2253           Cubrecanto 22mm Chapa Enc Rojo CA (1m) *2253*
#                                                 33221            Cubrecanto 22mm Chapa Maple CA (1m) *33221*
#                                                 75133           Cubrecanto 50mm Chapa Parota CA (1m) *75133*
#
# [6094 rows x 6 columns]

# %%
compras_sayer = compras.loc[compras['prod_línea'].isin(['00SAY', '0SAYC', '0SAYG', '0SAYL'])]
compras_sayer_vendedora = compras_sayer.groupby(['name', 'prod_línea', 'prod_código']).agg({'quantity':['count', 'sum', 'max', 'min', 'mean'], 'prod_descripción':['first']})
compras_sayer_vendedora
# Out:
#                                                             quantity        \
#                                                                count   sum
# name                                 prod_línea prod_código
# Brenda Luz Acosta Lopez              0SAYC      12971              1  1.00
#                                                 40147              1  1.00
#                                      0SAYG      12816              1  8.00
#                                                 12866              1  2.00
#                                                 12869              1  2.00
# ...                                                              ...   ...
# Yolanda Alejandra Rodriguez González 0SAYL      8984               2  3.00
#                                                 8986               1  1.00
#                                                 92                 4  9.00
#                                                 9312               3 18.00
#                                                 9960               4  9.00
#
#                                                                             \
#                                                              max  min mean
# name                                 prod_línea prod_código
# Brenda Luz Acosta Lopez              0SAYC      12971       1.00 1.00 1.00
#                                                 40147       1.00 1.00 1.00
#                                      0SAYG      12816       8.00 8.00 8.00
#                                                 12866       2.00 2.00 2.00
#                                                 12869       2.00 2.00 2.00
# ...                                                          ...  ...  ...
# Yolanda Alejandra Rodriguez González 0SAYL      8984        2.00 1.00 1.50
#                                                 8986        1.00 1.00 1.00
#                                                 92          3.00 1.00 2.25
#                                                 9312        8.00 2.00 6.00
#                                                 9960        3.00 1.00 2.25
#
#                                                                                             prod_descripción
#                                                                                                        first
# name                                 prod_línea prod_código
# Brenda Luz Acosta Lopez              0SAYC      12971          Tin/Ace Man-Sayer TS-6102 (19L) Negro *12971*
#                                                 40147             Laca Sayer LI-0102 (19L) Ind Negro *40147*
#                                      0SAYG      12816           Hidrolack Sayer HI-0815 (4Lt) Transp *12816*
#                                                 12866             Laca Sayer LI-0102 (4Lt) Ind Negro *12866*
#                                                 12869        Laca Sayer LI-0106 (4Lt) Ind Rojo Oxido *12869*
# ...                                                                                                      ...
# Yolanda Alejandra Rodriguez González 0SAYL      8984              Resanador Sayer RL-0020 (1/4) Roble *8984*
#                                                 8986                 Fondo Sayer UF-0042 (1Lt) Rapido *8986*
#                                                 92             Blanqueador Sayer AD-0300 (1Lt) N-1 P/Ma *92*
#                                                 9312           Tin/Ace Man-Sayer TS-6101 (1Lt) Blanco *9312*
#                                                 9960         Blanqueador Sayer AD-0301 (1Lt) N-2 P/Ma *9960*
#
# [1013 rows x 6 columns]

# %%
match mes:
    case 1:
        nombre_mes = 'Enero'
    case 2:
        nombre_mes = 'Febrero'
    case 3:
        nombre_mes = 'Marzo'
    case 4:
        nombre_mes = 'Abril'
    case 5:
        nombre_mes = 'Mayo'
    case 6:
        nombre_mes = 'Junio'
    case 7:
        nombre_mes = 'Julio'
    case 8:
        nombre_mes = 'Agosto'
    case 9:
        nombre_mes = 'Septiembre'
    case 10:
        nombre_mes = 'Octubre'
    case 11:
        nombre_mes = 'Noviembre'
    case 12:
        nombre_mes = 'Diciembre'

# %%
desktop_path = Path.home().joinpath('desktop')
archivo_path = desktop_path.joinpath(nombre_mes + '.xlsx')

writer = pd.ExcelWriter(archivo_path, engine="openpyxl")

compras.to_excel(writer, sheet_name='Total')
compras_linea.to_excel(writer, sheet_name='linea')
compras_linea_sale_team.to_excel(writer, sheet_name='linea_folio')
compras_linea_vendedora.to_excel(writer, sheet_name='linea_vendedora')
compras_almacen.to_excel(writer, sheet_name='almacen')
compras_modelo_negocios.to_excel(writer, sheet_name='modelo_negocios')
compras_folio_ventas.to_excel(writer, sheet_name='folio')
compras_vendedora.to_excel(writer, sheet_name='vendedora')

writer.close()
writer.handles = None
