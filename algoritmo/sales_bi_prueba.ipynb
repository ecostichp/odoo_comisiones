# %%
from wep import complete_df
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.float_format = '{:,.2f}'.format

# %%
from wep import descrip_sales_users_df

# %%
mes = complete_df[['salesman_id', 'quantity', 'price_subtotal']].groupby('salesman_id', dropna=False).sum()

ventas_mes = mes.reset_index(
).merge(
    descrip_sales_users_df, how='left', left_on='salesman_id', right_on='id'
).set_index(
    'salesman_id'
).drop(
    columns=['id', 'sale_team_id', 'state']
)

ventas_mes
# Out:
#              quantity  price_subtotal                                  name  \
# salesman_id
# 205         20,036.00      816,593.98               Brenda Luz Acosta Lopez
# 206             44.00        1,996.99                                   NaN
# 210         27,819.00    1,163,746.82                  Irma Carvajal Flores
# 211         14,579.17    1,448,714.41       Mayra Angelica Parada Manjarrez
# 212         13,808.30      276,871.92                  Reyna Arriaga Flores
# 213          3,032.00      315,472.17                  Yamilet Blanco Salas
# 216          8,711.00      324,389.40                     Nadia Santos Nava
# 218          9,929.78      213,998.99         Gladiz Melisa Galvez Espinoza
# 219          8,938.15      130,038.71               Viviana Montaño Inzunza
# 221         32,087.70      662,497.42      Karla Jaqueline Rivera Hernández
# 222         10,107.55      239,612.32  Yolanda Alejandra Rodriguez González
# 224         10,203.61      181,396.72                 Leticia Terán Salinas
# 227         11,752.85      193,370.05             Patricia Flores Pantaleón
# 233          3,723.00       99,044.14              Angela Carrillo Cárdenas
# 234          1,373.95       32,645.95                Yanin Becerril Barriga
# <NA>          -380.30       -4,375.04                                   NaN
#
#             sale_team_description business_model warehouse
# salesman_id
# 205                         CE A2             CE        A2
# 206                           NaN            NaN       NaN
# 210                         CE A1             CE        A1
# 211                         CE A1             CE        A1
# 212                        A1 CSL           Piso        A1
# 213                         CE A2             CE        A2
# 216                        A2 SJC           Piso        A2
# 218                        A1 CSL           Piso        A1
# 219                        A1 CSL           Piso        A1
# 221                        A2 SJC           Piso        A2
# 222                        A2 SJC           Piso        A2
# 224                        A1 CSL           Piso        A1
# 227                        A2 SJC           Piso        A2
# 233                        A2 SJC           Piso        A2
# 234                        A1 CSL           Piso        A1
# <NA>                          NaN            NaN       NaN

# %%
cols = ['quantity', 'price_subtotal']

wep = complete_df.loc[complete_df['salesman_id'] == 216, cols].groupby('name').sum()
wep
# wep.to_excel('wep.xlsx')
# Out:
#                    quantity  price_subtotal
# name
# F2-CC/2024/00073       3.00          318.12
# F2-CC/2024/00076      21.00          253.49
# F2-CC/2024/00079       6.00        1,710.59
# F2-CC/2024/00081      16.00        1,936.36
# F2-CC/2024/00084       3.00          424.80
# ...                     ...             ...
# F2-CC/2024/02144       1.00          432.25
# F2-CC/2024/02149     101.25           86.25
# F2-CC/2024/02150      25.00        1,785.80
# F2-CC/2024/02152       1.00          331.50
# RF2-CC/2024/00001    -12.00       -2,332.77
#
# [451 rows x 2 columns]

# %% [markdown]
# ## Algo de <span style="color: steelblue">BI</span>

# %%
ventas_mes.groupby('business_model').sum()[['quantity', 'price_subtotal']]
# Out:
#                  quantity  price_subtotal
# business_model
# CE              65,466.17    3,744,527.38
# Piso           110,635.89    2,353,865.62

# %%
ventas_mes.groupby('sale_team_description').sum()[['quantity', 'price_subtotal']]
# Out:
#                        quantity  price_subtotal
# sale_team_description
# A1 CSL                44,253.79      834,952.29
# A2 SJC                66,382.10    1,518,913.33
# CE A1                 42,398.17    2,612,461.23
# CE A2                 23,068.00    1,132,066.15

# %%
ventas_mes.groupby('warehouse').sum()[['quantity', 'price_subtotal']]
# Out:
#            quantity  price_subtotal
# warehouse
# A1        86,651.96    3,447,413.52
# A2        89,450.10    2,650,979.48

# %%
total = ventas_mes['price_subtotal'].sum()

pd.DataFrame(total, columns=['Total de Venta'], index=[0])
# Out:
#    Total de Venta
# 0    6,096,014.95
