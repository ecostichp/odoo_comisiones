# %%
import xmlrpc.client
import os

api_url = os.environ.get('ODOO_URL_API')
# api_db = os.environ.get('ODOO_DB_API')
api_db = os.environ.get('ODOO_DB_PRUEBA_API')
api_username = os.environ.get('ODOO_USERNAME_API')
api_clave = os.environ.get('ODOO_CLAVE_API')

common = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/common')
uid = common.authenticate(api_db, api_username, api_clave, {})
models = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/object')

# %%
ids = models.execute_kw(api_db, uid, api_clave, 'account.move', 'search', [["&", ("state", "=", "posted"), ("date", ">", "2024-04-19")]])
wep = models.execute_kw(api_db, uid, api_clave, 'account.move', 'read', [ids])
wep
# Out:
# [{'id': 50471,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'EBMX/2302/02/',
#   'sequence_number': 10,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [140880, 140885],
#   'message_partner_ids': [237, 15625],
#   'message_ids': [269027, 269026],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'name': 'EBMX/2302/02/0010',
#   'ref': 'Reversión de: EBMX/2302/02/0005',
#   'date': '2302-02-23',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [38, 'Efectivamente Pagado'],
#   'company_id': [2, 'La Casa Del Carpintero Ventas y Soluciones'],
#   'line_ids': [189196, 189197, 189198, 189199],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': [27561, 'F1-VS/2024/00588'],
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [32, 37, 33, 34, 38, 39],
#   'highest_name': 'EBMX/2302/02/0009',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'country_code': 'MX',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"2","date":"2302-02-23","journal_id":"38","line_189196_account_id":"197","line_189196_credit":"573.04","line_189196_debit":"0.00","line_189196_name":"F1-VS/2024/00588","line_189196_partner_id":"15625","line_189197_account_id":"197","line_189197_credit":"0.00","line_189197_debit":"573.04","line_189197_name":"F1-VS/2024/00588","line_189197_partner_id":"15625","line_189198_account_id":"185","line_189198_credit":"91.69","line_189198_debit":"0.00","line_189198_name":"16% VyS","line_189198_partner_id":"15625","line_189199_account_id":"183","line_189199_credit":"0.00","line_189199_debit":"91.69","line_189199_name":"16% VyS","line_189199_partner_id":"15625","name":"EBMX/2302/02/0010"}',
#   'invoice_line_ids': [189196, 189197, 189198, 189199],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-27',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': [15625, 'FRONT ROW HS'],
#   'commercial_partner_id': [15625, 'FRONT ROW HS'],
#   'partner_shipping_id': False,
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 664.73,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 664.73,
#   'amount_total_in_currency_signed': 664.73,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'SEISCIENTOS SESENTA Y CUATRO PESOS 73/100 M.N',
#   'reversed_entry_id': [50470, 'EBMX/2302/02/0005 (F1-VS/2024/00588)'],
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'FRONT ROW HS',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [15625, 'FRONT ROW HS'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'EBMX/2302/02/0010 (Reversión de: EBMX/2302/02/0005)',
#   'create_uid': [236, 'Bianca Sánchez Valenciano'],
#   'create_date': '2024-03-27 16:56:15',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-03-27 16:56:15',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': False,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': False,
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': False,
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 50472,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'EBMX/2302/02/',
#   'sequence_number': 9,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [140881, 140886],
#   'message_partner_ids': [237, 15625],
#   'message_ids': [269029, 269028],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'name': 'EBMX/2302/02/0009',
#   'ref': 'Reversión de: EBMX/2302/02/0004',
#   'date': '2302-02-23',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [38, 'Efectivamente Pagado'],
#   'company_id': [2, 'La Casa Del Carpintero Ventas y Soluciones'],
#   'line_ids': [189200, 189201, 189202, 189203],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': [24556, 'F1-VS/2024/00527'],
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [32, 37, 33, 34, 38, 39],
#   'highest_name': 'EBMX/2302/02/0010',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'country_code': 'MX',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"2","date":"2302-02-23","journal_id":"38","line_189200_account_id":"197","line_189200_credit":"1461.23","line_189200_debit":"0.00","line_189200_name":"F1-VS/2024/00527","line_189200_partner_id":"15625","line_189201_account_id":"197","line_189201_credit":"0.00","line_189201_debit":"1461.23","line_189201_name":"F1-VS/2024/00527","line_189201_partner_id":"15625","line_189202_account_id":"185","line_189202_credit":"233.80","line_189202_debit":"0.00","line_189202_name":"16% VyS","line_189202_partner_id":"15625","line_189203_account_id":"183","line_189203_credit":"0.00","line_189203_debit":"233.80","line_189203_name":"16% VyS","line_189203_partner_id":"15625","name":"EBMX/2302/02/0009"}',
#   'invoice_line_ids': [189200, 189201, 189202, 189203],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-27',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': [15625, 'FRONT ROW HS'],
#   'commercial_partner_id': [15625, 'FRONT ROW HS'],
#   'partner_shipping_id': False,
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 1695.03,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 1695.03,
#   'amount_total_in_currency_signed': 1695.03,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'MIL SEISCIENTOS NOVENTA Y CINCO PESOS 03/100 M.N',
#   'reversed_entry_id': [50469, 'EBMX/2302/02/0004 (F1-VS/2024/00527)'],
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'FRONT ROW HS',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [15625, 'FRONT ROW HS'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'EBMX/2302/02/0009 (Reversión de: EBMX/2302/02/0004)',
#   'create_uid': [236, 'Bianca Sánchez Valenciano'],
#   'create_date': '2024-03-27 16:56:15',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-03-27 16:56:15',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': False,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': False,
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': False,
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 50473,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'EBMX/2302/02/',
#   'sequence_number': 8,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [140882, 140887],
#   'message_partner_ids': [237, 15625],
#   'message_ids': [269031, 269030],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'name': 'EBMX/2302/02/0008',
#   'ref': 'Reversión de: EBMX/2302/02/0003',
#   'date': '2302-02-23',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [38, 'Efectivamente Pagado'],
#   'company_id': [2, 'La Casa Del Carpintero Ventas y Soluciones'],
#   'line_ids': [189204, 189205, 189206, 189207],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': [23475, 'F1-VS/2024/00506'],
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [32, 37, 33, 34, 38, 39],
#   'highest_name': 'EBMX/2302/02/0010',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'country_code': 'MX',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"2","date":"2302-02-23","journal_id":"38","line_189204_account_id":"197","line_189204_credit":"227.19","line_189204_debit":"0.00","line_189204_name":"F1-VS/2024/00506","line_189204_partner_id":"15625","line_189205_account_id":"197","line_189205_credit":"0.00","line_189205_debit":"227.19","line_189205_name":"F1-VS/2024/00506","line_189205_partner_id":"15625","line_189206_account_id":"185","line_189206_credit":"36.35","line_189206_debit":"0.00","line_189206_name":"16% VyS","line_189206_partner_id":"15625","line_189207_account_id":"183","line_189207_credit":"0.00","line_189207_debit":"36.35","line_189207_name":"16% VyS","line_189207_partner_id":"15625","name":"EBMX/2302/02/0008"}',
#   'invoice_line_ids': [189204, 189205, 189206, 189207],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-27',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': [15625, 'FRONT ROW HS'],
#   'commercial_partner_id': [15625, 'FRONT ROW HS'],
#   'partner_shipping_id': False,
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 263.54,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 263.54,
#   'amount_total_in_currency_signed': 263.54,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'DOSCIENTOS SESENTA Y TRES PESOS 54/100 M.N',
#   'reversed_entry_id': [50468, 'EBMX/2302/02/0003 (F1-VS/2024/00506)'],
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'FRONT ROW HS',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [15625, 'FRONT ROW HS'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'EBMX/2302/02/0008 (Reversión de: EBMX/2302/02/0003)',
#   'create_uid': [236, 'Bianca Sánchez Valenciano'],
#   'create_date': '2024-03-27 16:56:15',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-03-27 16:56:15',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': False,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': False,
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': False,
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 50474,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'EBMX/2302/02/',
#   'sequence_number': 7,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [140883, 140888],
#   'message_partner_ids': [237, 15625],
#   'message_ids': [269033, 269032],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'name': 'EBMX/2302/02/0007',
#   'ref': 'Reversión de: EBMX/2302/02/0002',
#   'date': '2302-02-23',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [38, 'Efectivamente Pagado'],
#   'company_id': [2, 'La Casa Del Carpintero Ventas y Soluciones'],
#   'line_ids': [189208, 189209, 189210, 189211],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': [11848, 'F1-VS/2024/00298'],
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [32, 37, 33, 34, 38, 39],
#   'highest_name': 'EBMX/2302/02/0010',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'country_code': 'MX',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"2","date":"2302-02-23","journal_id":"38","line_189208_account_id":"197","line_189208_credit":"4866.10","line_189208_debit":"0.00","line_189208_name":"F1-VS/2024/00298","line_189208_partner_id":"15625","line_189209_account_id":"197","line_189209_credit":"0.00","line_189209_debit":"4866.10","line_189209_name":"F1-VS/2024/00298","line_189209_partner_id":"15625","line_189210_account_id":"185","line_189210_credit":"778.58","line_189210_debit":"0.00","line_189210_name":"16% VyS","line_189210_partner_id":"15625","line_189211_account_id":"183","line_189211_credit":"0.00","line_189211_debit":"778.58","line_189211_name":"16% VyS","line_189211_partner_id":"15625","name":"EBMX/2302/02/0007"}',
#   'invoice_line_ids': [189208, 189209, 189210, 189211],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-27',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': [15625, 'FRONT ROW HS'],
#   'commercial_partner_id': [15625, 'FRONT ROW HS'],
#   'partner_shipping_id': False,
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 5644.68,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 5644.68,
#   'amount_total_in_currency_signed': 5644.68,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'CINCO MIL SEISCIENTOS CUARENTA Y CUATRO PESOS 68/100 M.N',
#   'reversed_entry_id': [50467, 'EBMX/2302/02/0002 (F1-VS/2024/00298)'],
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'FRONT ROW HS',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [15625, 'FRONT ROW HS'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'EBMX/2302/02/0007 (Reversión de: EBMX/2302/02/0002)',
#   'create_uid': [236, 'Bianca Sánchez Valenciano'],
#   'create_date': '2024-03-27 16:56:15',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-03-27 16:56:15',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': False,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': False,
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': False,
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 50475,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'EBMX/2302/02/',
#   'sequence_number': 6,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [140884, 140889],
#   'message_partner_ids': [237, 15625],
#   'message_ids': [269035, 269034],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'name': 'EBMX/2302/02/0006',
#   'ref': 'Reversión de: EBMX/2302/02/0001',
#   'date': '2302-02-23',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [38, 'Efectivamente Pagado'],
#   'company_id': [2, 'La Casa Del Carpintero Ventas y Soluciones'],
#   'line_ids': [189212, 189213, 189214, 189215],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': [5170, 'F1-VS/2024/00139'],
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [32, 37, 33, 34, 38, 39],
#   'highest_name': 'EBMX/2302/02/0010',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'country_code': 'MX',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"2","date":"2302-02-23","journal_id":"38","line_189212_account_id":"197","line_189212_credit":"1297.55","line_189212_debit":"0.00","line_189212_name":"F1-VS/2024/00139","line_189212_partner_id":"15625","line_189213_account_id":"197","line_189213_credit":"0.00","line_189213_debit":"1297.55","line_189213_name":"F1-VS/2024/00139","line_189213_partner_id":"15625","line_189214_account_id":"185","line_189214_credit":"207.61","line_189214_debit":"0.00","line_189214_name":"16% VyS","line_189214_partner_id":"15625","line_189215_account_id":"183","line_189215_credit":"0.00","line_189215_debit":"207.61","line_189215_name":"16% VyS","line_189215_partner_id":"15625","name":"EBMX/2302/02/0006"}',
#   'invoice_line_ids': [189212, 189213, 189214, 189215],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-27',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': [15625, 'FRONT ROW HS'],
#   'commercial_partner_id': [15625, 'FRONT ROW HS'],
#   'partner_shipping_id': False,
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 1505.16,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 1505.16,
#   'amount_total_in_currency_signed': 1505.16,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'MIL QUINIENTOS CINCO PESOS 16/100 M.N',
#   'reversed_entry_id': [50466, 'EBMX/2302/02/0001 (F1-VS/2024/00139)'],
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'FRONT ROW HS',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [15625, 'FRONT ROW HS'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'EBMX/2302/02/0006 (Reversión de: EBMX/2302/02/0001)',
#   'create_uid': [236, 'Bianca Sánchez Valenciano'],
#   'create_date': '2024-03-27 16:56:15',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-03-27 16:56:15',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': False,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': False,
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': False,
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 50470,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'EBMX/2302/02/',
#   'sequence_number': 5,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [140867, 140872],
#   'message_partner_ids': [237, 15625],
#   'message_ids': [269011],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'name': 'EBMX/2302/02/0005',
#   'ref': 'F1-VS/2024/00588',
#   'date': '2302-02-23',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [38, 'Efectivamente Pagado'],
#   'company_id': [2, 'La Casa Del Carpintero Ventas y Soluciones'],
#   'line_ids': [189192, 189193, 189194, 189195],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': [27561, 'F1-VS/2024/00588'],
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [32, 37, 33, 34, 38, 39],
#   'highest_name': 'EBMX/2302/02/0010',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'country_code': 'MX',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"2","date":"2302-02-23","journal_id":"38","line_189192_account_id":"197","line_189192_credit":"0.00","line_189192_debit":"573.04","line_189192_name":"F1-VS/2024/00588","line_189192_partner_id":"15625","line_189193_account_id":"197","line_189193_credit":"573.04","line_189193_debit":"0.00","line_189193_name":"F1-VS/2024/00588","line_189193_partner_id":"15625","line_189194_account_id":"185","line_189194_credit":"0.00","line_189194_debit":"91.69","line_189194_name":"16% VyS","line_189194_partner_id":"15625","line_189195_account_id":"183","line_189195_credit":"91.69","line_189195_debit":"0.00","line_189195_name":"16% VyS","line_189195_partner_id":"15625","name":"EBMX/2302/02/0005"}',
#   'invoice_line_ids': [189192, 189193, 189194, 189195],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-27',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': [15625, 'FRONT ROW HS'],
#   'commercial_partner_id': [15625, 'FRONT ROW HS'],
#   'partner_shipping_id': False,
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 664.73,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 664.73,
#   'amount_total_in_currency_signed': 664.73,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'SEISCIENTOS SESENTA Y CUATRO PESOS 73/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [50471],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'FRONT ROW HS',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [15625, 'FRONT ROW HS'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'EBMX/2302/02/0005 (F1-VS/2024/00588)',
#   'create_uid': [236, 'Bianca Sánchez Valenciano'],
#   'create_date': '2024-03-27 16:55:21',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-03-27 16:55:21',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': False,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': False,
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': False,
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
# ...
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [8, 'CE A2'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 64121,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'EBMX/2024/04/',
#   'sequence_number': 4091,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [176792],
#   'message_partner_ids': [3],
#   'message_ids': [339674],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'name': 'EBMX/2024/04/4091',
#   'ref': 'PV1A2/2024/04/1680',
#   'date': '2024-04-20',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [18, 'Efectivamente Pagado'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [241036, 241037, 241038, 241039],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': [54471, 'account.partial.reconcile,54471'],
#   'tax_cash_basis_origin_move_id': [64115, 'PV1A2/2024/04/1680 (POS/00195)'],
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'EBMX/2024/04/4145',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'country_code': 'MX',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-04-20","journal_id":"18","line_241036_account_id":"71","line_241036_credit":"0.00","line_241036_debit":"0.52","line_241036_name":"16%","line_241036_partner_id":"False","line_241037_account_id":"71","line_241037_credit":"0.52","line_241037_debit":"0.00","line_241037_name":"16%","line_241037_partner_id":"False","line_241038_account_id":"85","line_241038_credit":"0.00","line_241038_debit":"3.26","line_241038_name":"PV1A2/2024/04/1680","line_241038_partner_id":"False","line_241039_account_id":"85","line_241039_credit":"3.26","line_241039_debit":"0.00","line_241039_name":"PV1A2/2024/04/1680","line_241039_partner_id":"False","name":"EBMX/2024/04/4091"}',
#   'invoice_line_ids': [241036, 241037, 241038, 241039],
#   'invoice_date': False,
#   'invoice_date_due': '2024-04-20',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': False,
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 3.78,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 3.78,
#   'amount_total_in_currency_signed': 3.78,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'TRES PESOS 78/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Lic. Costich',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': False,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'EBMX/2024/04/4091 (PV1A2/2024/04/1680)',
#   'create_uid': [2, 'Lic. Costich'],
#   'create_date': '2024-04-20 19:17:50',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-20 19:17:50',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': False,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': False,
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [8, 'CE A2'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 64119,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'E2-CC/2024/',
#   'sequence_number': 187,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [176790],
#   'message_partner_ids': [3],
#   'message_ids': [339672],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'name': 'E2-CC/2024/00187',
#   'ref': False,
#   'date': '2024-04-20',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [91, 'Efectivo A2'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [241027, 241028],
#   'payment_id': False,
#   'statement_line_id': [473, 'E2-CC/2024/00187'],
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'E2-CC/2024/00188',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'country_code': 'MX',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-04-20","journal_id":"91","line_241027_account_id":"496","line_241027_credit":"0.00","line_241027_debit":"12093.49","line_241027_name":"POS/00195","line_241027_partner_id":"False","line_241028_account_id":"50","line_241028_credit":"12093.49","line_241028_debit":"0.00","line_241028_name":"POS/00195","line_241028_partner_id":"False","name":"E2-CC/2024/00187"}',
#   'invoice_line_ids': [241027, 241028],
#   'invoice_date': False,
#   'invoice_date_due': '2024-04-20',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': False,
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 12093.49,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 12093.49,
#   'amount_total_in_currency_signed': 12093.49,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'DOCE MIL NOVENTA Y TRES PESOS 49/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Lic. Costich',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'E2-CC/2024/00187',
#   'create_uid': [2, 'Lic. Costich'],
#   'create_date': '2024-04-20 19:17:50',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-20 19:17:50',
#   'payment_ids': [],
#   'statement_line_ids': [473],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-04-20 12:17:51',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [8, 'CE A2'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False}]

# %%
# ids = models.execute_kw(api_db, uid, api_clave, 'account.move', 'search', [[("pos_order_ids", "=", 13559)]])
wep = models.execute_kw(api_db, uid, api_clave, 'account.move', 'read', [[44148]])
wep
# Out:
# [{'id': 44148,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'F1-CC/2024/',
#   'sequence_number': 3971,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '/my/invoices/44148',
#   'access_token': False,
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [124236, 124237],
#   'message_partner_ids': [16357, 15408],
#   'message_ids': [339765, 317715, 237407, 237391, 237390, 237389],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 2,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': [37899, 'F1-CC_2024_03971.pdf'],
#   'name': 'F1-CC/2024/03971',
#   'ref': 'PdV CSL/3918',
#   'date': '2024-03-18',
#   'state': 'posted',
#   'move_type': 'out_invoice',
#   'is_storno': False,
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [165531,
#    165532,
#    165533,
#    165534,
#    165535,
#    165536,
#    165537,
#    165538,
#    165539,
#    165540],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [64182, 59670],
#   'always_tax_exigible': False,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [10, 90, 112, 113],
#   'highest_name': 'F1-CC/2024/05708',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Factura',
#   'country_code': 'MX',
#   'attachment_ids': [39528, 37897],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-03-18","journal_id":"10","line_165531_account_id":"85","line_165531_credit":"2836.08","line_165531_debit":"0.00","line_165531_name":"[11283] Fondo Sayer UF-0042 (19L) Rapido *11283*","line_165531_partner_id":"15408","line_165532_account_id":"85","line_165532_credit":"1852.61","line_165532_debit":"0.00","line_165532_name":"[16926] Catal Sayer UC-0042 (5Lt) P/Fondo Rapido *16926*","line_165532_partner_id":"15408","line_165533_account_id":"85","line_165533_credit":"3225.03","line_165533_debit":"0.00","line_165533_name":"[9511] Barniz Sayer UM-1030 (19L) Semi Mate *9511*","line_165533_partner_id":"15408","line_165534_account_id":"85","line_165534_credit":"2323.19","line_165534_debit":"0.00","line_165534_name":"[16505] Catal Sayer UC-1010 (5Lt) P/Uremate *16505*","line_165534_partner_id":"15408","line_165535_account_id":"85","line_165535_credit":"89.71","line_165535_debit":"0.00","line_165535_name":"[1933] Estopa (Bolsa 1Kg) \\"Ardilla\\" *1933*","line_165535_partner_id":"15408","line_165536_account_id":"85","line_165536_credit":"43.18","line_165536_debit":"0.00","line_165536_name":"[80023] GUANTES PRETUL #23261 GU-LIM-GP *80023*","line_165536_partner_id":"15408","line_165537_account_id":"85","line_165537_credit":"836.66","line_165537_debit":"0.00","line_165537_name":"[13169] Thinner Sayer D-0002 (20L) Estandar *13169*","line_165537_partner_id":"15408","line_165538_account_id":"85","line_165538_credit":"1951.67","line_165538_debit":"0.00","line_165538_name":"[9547] Diluyente Sayer D-0500 (20L) P/Poliureta *9547*","line_165538_partner_id":"15408","line_165539_account_id":"73","line_165539_credit":"2105.30","line_165539_debit":"0.00","line_165539_name":"16%","line_165539_partner_id":"15408","line_165540_account_id":"49","line_165540_credit":"0.00","line_165540_debit":"15263.43","line_165540_name":"F1-CC/2024/03971","line_165540_partner_id":"15408","name":"F1-CC/2024/03971"}',
#   'invoice_line_ids': [165531,
#    165532,
#    165533,
#    165534,
#    165535,
#    165536,
#    165537,
#    165538],
#   'invoice_date': '2024-03-18',
#   'invoice_date_due': '2024-05-02',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': [5, '45 Days'],
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'commercial_partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'partner_shipping_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': 'F1-CC/2024/03971',
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': {'outstanding': True,
#    'content': [{'journal_name': 'POS/00188',
#      'amount': 18000.0,
#      'currency_id': 32,
#      'id': 231934,
#      'move_id': 61765,
#      'date': '2024-04-13',
#      'account_payment_id': False}],
#    'move_id': 44148,
#    'title': 'Créditos pendientes'},
#   'invoice_has_outstanding': True,
#   'invoice_payments_widget': {'title': 'Menos pagos',
#    'outstanding': False,
#    'content': [{'name': 'POS/00079 - Crédito del cliente',
#      'journal_name': 'Punto De Venta A1',
#      'company_name': False,
#      'amount': 2388.73,
#      'currency_id': 32,
#      'date': '2024-02-10',
#      'partial_id': 50764,
#      'account_payment_id': False,
#      'payment_method_name': False,
#      'move_id': 23005,
#      'ref': 'PV1A1/2024/02/0747 (POS/00079)',
#      'is_exchange': False,
#      'amount_company_currency': '$\xa010,000.00',
#      'amount_foreign_currency': False,
#      'pos_payment_name': False},
#     {'name': 'POS/00195 - Crédito del cliente',
#      'journal_name': 'Punto De Venta A2',
#      'company_name': False,
#      'amount': 1895.84,
#      'currency_id': 32,
#      'date': '2024-04-20',
#      'partial_id': 54566,
#      'account_payment_id': False,
#      'payment_method_name': False,
#      'move_id': 64115,
#      'ref': 'PV1A2/2024/04/1680 (POS/00195)',
#      'is_exchange': False,
#      'amount_company_currency': '$\xa05,000.00',
#      'amount_foreign_currency': False,
#      'pos_payment_name': False}]},
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': -1,
#   'amount_untaxed': 13158.13,
#   'amount_tax': 2105.3,
#   'amount_total': 15263.43,
#   'amount_residual': 10978.86,
#   'amount_untaxed_signed': 13158.13,
#   'amount_tax_signed': 2105.3,
#   'amount_total_signed': 15263.43,
#   'amount_total_in_currency_signed': 15263.43,
#   'amount_residual_signed': 10978.86,
#   'tax_totals': {'amount_untaxed': 13158.130000000001,
#    'amount_total': 15263.43,
#    'formatted_amount_total': '$\xa015,263.43',
#    'formatted_amount_untaxed': '$\xa013,158.13',
#    'groups_by_subtotal': {'Importe sin impuestos': [{'group_key': 3,
#       'tax_group_id': 3,
#       'tax_group_name': 'VAT 16%',
#       'tax_group_amount': 2105.3,
#       'tax_group_base_amount': 13158.130000000001,
#       'formatted_tax_group_amount': '$\xa02,105.30',
#       'formatted_tax_group_base_amount': '$\xa013,158.13'}]},
#    'subtotals': [{'name': 'Importe sin impuestos',
#      'amount': 13158.130000000001,
#      'formatted_amount': '$\xa013,158.13'}],
#    'subtotals_order': ['Importe sin impuestos'],
#    'display_tax_base': False},
#   'payment_state': 'partial',
#   'amount_total_words': 'QUINCE MIL DOSCIENTOS SESENTA Y TRES PESOS 43/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'GUADALUPE (SR.PINACHO)',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': True,
#   'is_being_sent': False,
#   'invoice_user_id': [237, 'Rosa Brenda Avilez Ceseña'],
#   'user_id': [237, 'Rosa Brenda Avilez Ceseña'],
#   'invoice_origin': 'PdV CSL/3918',
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': [37899, 'F1-CC_2024_03971.pdf'],
#   'invoice_pdf_report_file': '...',
#   'invoice_filter_type_domain': 'sale',
#   'bank_partner_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': False,
#   'show_reset_to_draft_button': False,
#   'partner_credit_warning': '',
#   'partner_credit': 25286.510000000002,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': True,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'F1-CC/2024/03971 (PdV CSL/3918)',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-18 15:13:57',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:41',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [11496],
#   'l10n_mx_edi_payment_document_ids': [11496],
#   'l10n_mx_edi_document_ids': [11496],
#   'l10n_mx_edi_cfdi_state': 'sent',
#   'l10n_mx_edi_cfdi_sat_state': 'valid',
#   'l10n_mx_edi_cfdi_attachment_id': [37897,
#    'F1-CC-F1-CC202403971-MX-Invoice-4.0.xml'],
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-03-18 08:13:58',
#   'l10n_mx_edi_usage': 'S01',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': '64299B3B-FEDA-573D-B7F4-8869F08B8D25',
#   'l10n_mx_edi_cfdi_supplier_rfc': 'CCC020129T26',
#   'l10n_mx_edi_cfdi_customer_rfc': 'XAXX010101000',
#   'l10n_mx_edi_cfdi_amount': 15263.43,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': 'PUE',
#   'l10n_mx_edi_cfdi_to_public': True,
#   'pos_order_ids': [9613],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [5, 'A1 CSL'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False}]

# %%
account_move_line_fields = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'fields_get', [])

list_fields = list(account_move_line_fields.keys())
list_fields.remove('compute_all_tax')

# %%
ids2 = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'search', [['&', ("move_id", "=", 64115), ("partner_id", "=", 15408)]])
wep2 = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'read', [ids2], {'fields': list_fields})
wep2
# Out:
# [{'id': 241026,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [64115, 'PV1A2/2024/04/1680 (POS/00195)'],
#   'journal_id': [92, 'Punto De Venta A2'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'PV1A2/2024/04/1680',
#   'parent_state': 'posted',
#   'date': '2024-04-20',
#   'invoice_date': False,
#   'ref': 'POS/00195',
#   'is_storno': False,
#   'sequence': 100,
#   'move_type': 'entry',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'POS/00195 - Crédito del cliente',
#   'debit': 0.0,
#   'credit': 5000.0,
#   'balance': -5000.0,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': -5000.0,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [54556, 54558, 54560, 54562, 54564, 54566],
#   'matched_credit_ids': [],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'product',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 1.0,
#   'date_maturity': False,
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': False,
#   'tax_key': {'id': 241026},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': False,
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'PV1A2/2024/04/1680 (POS/00195) POS/00195 - Crédito del cliente',
#   'create_uid': [2, 'Lic. Costich'],
#   'create_date': '2024-04-20 19:17:50',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:41',
#   'move_attachment_ids': [],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': False}]

# %%
ids3 = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'search', [['&', ("move_type", "=", "out_invoice"), ("matching_number", "=", "P19535")]])
wep3 = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'read', [ids3], {'fields': list_fields})
wep3
# Out:
# [{'id': 212734,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [56778, 'F1-CC/2024/05053 (PdV CSL/5009)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/05053',
#   'parent_state': 'posted',
#   'date': '2024-04-08',
#   'invoice_date': '2024-04-08',
#   'ref': 'PdV CSL/5009',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/05053',
#   'debit': 78.88,
#   'credit': 0.0,
#   'balance': 78.88,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 78.88,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54564],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-08',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 56778,
#    'date_maturity': '2024-05-08',
#    'discount_date': False},
#   'tax_key': {'id': 212734},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-08',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/05053 (PdV CSL/5009) F1-CC/2024/05053',
#   'create_uid': [242, 'Maria Guadalupe Camacho Escalante'],
#   'create_date': '2024-04-08 15:15:11',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:22',
#   'move_attachment_ids': [54816, 49509, 49508],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/5009'},
#  {'id': 174576,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [46571, 'F1-CC/2024/04239 (PdV CSL/4189)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/04239',
#   'parent_state': 'posted',
#   'date': '2024-03-21',
#   'invoice_date': '2024-03-21',
#   'ref': 'PdV CSL/4189',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/04239',
#   'debit': 536.04,
#   'credit': 0.0,
#   'balance': 536.04,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 536.04,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54562],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-05',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 46571,
#    'date_maturity': '2024-05-05',
#    'discount_date': False},
#   'tax_key': {'id': 174576},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-05',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/04239 (PdV CSL/4189) F1-CC/2024/04239',
#   'create_uid': [212, 'Reyna Arriaga Flores'],
#   'create_date': '2024-03-21 23:31:59',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:14',
#   'move_attachment_ids': [40469, 40176, 40175],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/4189'},
#  {'id': 173566,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [46272, 'F1-CC/2024/04198 (PdV CSL/4148)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/04198',
#   'parent_state': 'posted',
#   'date': '2024-03-21',
#   'invoice_date': '2024-03-21',
#   'ref': 'PdV CSL/4148',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/04198',
#   'debit': 1733.37,
#   'credit': 0.0,
#   'balance': 1733.37,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 1733.37,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54558],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-05',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 46272,
#    'date_maturity': '2024-05-05',
#    'discount_date': False},
#   'tax_key': {'id': 173566},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-05',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/04198 (PdV CSL/4148) F1-CC/2024/04198',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-21 18:18:06',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:39:36',
#   'move_attachment_ids': [40470, 39818, 39817],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/4148'},
#  {'id': 170904,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [45604, 'F1-CC/2024/04123 (PdV CSL/4073)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/04123',
#   'parent_state': 'posted',
#   'date': '2024-03-20',
#   'invoice_date': '2024-03-20',
#   'ref': 'PdV CSL/4073',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/04123',
#   'debit': 390.32,
#   'credit': 0.0,
#   'balance': 390.32,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 390.32,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54560],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-04',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 45604,
#    'date_maturity': '2024-05-04',
#    'discount_date': False},
#   'tax_key': {'id': 170904},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-04',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/04123 (PdV CSL/4073) F1-CC/2024/04123',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-20 18:43:58',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:03',
#   'move_attachment_ids': [40467, 39177, 39176],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/4073'},
#  {'id': 168862,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [45067, 'F1-CC/2024/04072 (PdV CSL/4022)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/04072',
#   'parent_state': 'posted',
#   'date': '2024-03-19',
#   'invoice_date': '2024-03-19',
#   'ref': 'PdV CSL/4022',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/04072',
#   'debit': 365.55,
#   'credit': 0.0,
#   'balance': 365.55,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 365.55,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54556],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-03',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 45067,
#    'date_maturity': '2024-05-03',
#    'discount_date': False},
#   'tax_key': {'id': 168862},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-03',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/04072 (PdV CSL/4022) F1-CC/2024/04072',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-19 21:18:14',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:39:24',
#   'move_attachment_ids': [40461, 38690, 38689],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/4022'},
#  {'id': 165540,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [44148, 'F1-CC/2024/03971 (PdV CSL/3918)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/03971',
#   'parent_state': 'posted',
#   'date': '2024-03-18',
#   'invoice_date': '2024-03-18',
#   'ref': 'PdV CSL/3918',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/03971',
#   'debit': 15263.43,
#   'credit': 0.0,
#   'balance': 15263.43,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 15263.43,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 10978.86,
#   'amount_residual_currency': 10978.86,
#   'reconciled': False,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [50764, 54566],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-02',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 44148,
#    'date_maturity': '2024-05-02',
#    'discount_date': False},
#   'tax_key': {'id': 165540},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-02',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/03971 (PdV CSL/3918) F1-CC/2024/03971',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-18 15:13:57',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:41',
#   'move_attachment_ids': [39528, 37899, 37897],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/3918'},
#  {'id': 87275,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [23359, 'F1-CC/2024/02164 (PdV CSL/2089)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/02164',
#   'parent_state': 'posted',
#   'date': '2024-02-12',
#   'invoice_date': '2024-02-12',
#   'ref': 'PdV CSL/2089',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/02164',
#   'debit': 136.91,
#   'credit': 0.0,
#   'balance': 136.91,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 136.91,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19602],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-27',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 23359,
#    'date_maturity': '2024-02-27',
#    'discount_date': False},
#   'tax_key': {'id': 87275},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-27',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/02164 (PdV CSL/2089) F1-CC/2024/02164',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-12 15:06:58',
#   'write_uid': [206, 'Mariana Araceli Carvajal Flores'],
#   'write_date': '2024-02-13 01:10:19',
#   'move_attachment_ids': [20334, 19643, 19642],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/2089'},
#  {'id': 85103,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [22743, 'F1-CC/2024/02125 (PdV CSL/2044)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/02125',
#   'parent_state': 'posted',
#   'date': '2024-02-10',
#   'invoice_date': '2024-02-10',
#   'ref': 'PdV CSL/2044',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/02125',
#   'debit': 380.33,
#   'credit': 0.0,
#   'balance': 380.33,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 380.33,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19600],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-25',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 22743,
#    'date_maturity': '2024-02-25',
#    'discount_date': False},
#   'tax_key': {'id': 85103},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-25',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/02125 (PdV CSL/2044) F1-CC/2024/02125',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-10 16:14:05',
#   'write_uid': [206, 'Mariana Araceli Carvajal Flores'],
#   'write_date': '2024-02-12 18:46:45',
#   'move_attachment_ids': [19859, 19084, 19083],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/2044'},
#  {'id': 82561,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [22014, 'F1-CC/2024/02065 (PdV CSL/1984)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/02065',
#   'parent_state': 'posted',
#   'date': '2024-02-09',
#   'invoice_date': '2024-02-09',
#   'ref': 'PdV CSL/1984',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/02065',
#   'debit': 3764.56,
#   'credit': 0.0,
#   'balance': 3764.56,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 3764.56,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19598],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-24',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 22014,
#    'date_maturity': '2024-02-24',
#    'discount_date': False},
#   'tax_key': {'id': 82561},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-24',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/02065 (PdV CSL/1984) F1-CC/2024/02065',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-09 15:35:06',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:54',
#   'move_attachment_ids': [18557, 18437, 18436],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1984'},
#  {'id': 75579,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [20035, 'F1-CC/2024/01919 (PdV CSL/1837)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01919',
#   'parent_state': 'posted',
#   'date': '2024-02-06',
#   'invoice_date': '2024-02-06',
#   'ref': 'PdV CSL/1837',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01919',
#   'debit': 625.81,
#   'credit': 0.0,
#   'balance': 625.81,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 625.81,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19596],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-21',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 20035,
#    'date_maturity': '2024-02-21',
#    'discount_date': False},
#   'tax_key': {'id': 75579},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-21',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01919 (PdV CSL/1837) F1-CC/2024/01919',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-06 18:27:08',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:47',
#   'move_attachment_ids': [17215, 17043, 16529, 16528],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1837'},
#  {'id': 72867,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [19245, 'F1-CC/2024/01832 (PdV CSL/1750)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01832',
#   'parent_state': 'posted',
#   'date': '2024-02-05',
#   'invoice_date': '2024-02-05',
#   'ref': 'PdV CSL/1750',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01832',
#   'debit': 242.29,
#   'credit': 0.0,
#   'balance': 242.29,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 242.29,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19594],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-20',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 19245,
#    'date_maturity': '2024-02-20',
#    'discount_date': False},
#   'tax_key': {'id': 72867},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-20',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01832 (PdV CSL/1750) F1-CC/2024/01832',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-05 15:13:59',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:40',
#   'move_attachment_ids': [17096, 17042, 15925, 15924],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1750'},
#  {'id': 70249,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [18525, 'F1-CC/2024/01750 (PdV CSL/1695)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01750',
#   'parent_state': 'posted',
#   'date': '2024-02-03',
#   'invoice_date': '2024-02-03',
#   'ref': 'PdV CSL/1695',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01750',
#   'debit': 246.63,
#   'credit': 0.0,
#   'balance': 246.63,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 246.63,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19590],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-18',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 18525,
#    'date_maturity': '2024-02-18',
#    'discount_date': False},
#   'tax_key': {'id': 70249},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-18',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01750 (PdV CSL/1695) F1-CC/2024/01750',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-03 15:42:49',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:24',
#   'move_attachment_ids': [15341, 15340],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1695'},
#  {'id': 70238,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [18521, 'F1-CC/2024/01749 (PdV CSL/1694)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01749',
#   'parent_state': 'posted',
#   'date': '2024-02-03',
#   'invoice_date': '2024-02-03',
#   'ref': 'PdV CSL/1694',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01749',
#   'debit': 1609.52,
#   'credit': 0.0,
#   'balance': 1609.52,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 1609.52,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19592],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-18',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 18521,
#    'date_maturity': '2024-02-18',
#    'discount_date': False},
#   'tax_key': {'id': 70238},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-18',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01749 (PdV CSL/1694) F1-CC/2024/01749',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-03 15:30:45',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:33',
#   'move_attachment_ids': [15333, 15332],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1694'},
#  {'id': 65116,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [17191, 'F1-CC/2024/01645'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01645',
#   'parent_state': 'posted',
#   'date': '2024-02-01',
#   'invoice_date': '2024-02-01',
#   'ref': False,
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01645',
#   'debit': 576.6,
#   'credit': 0.0,
#   'balance': 576.6,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 576.6,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19588],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-16',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 17191,
#    'date_maturity': '2024-02-16',
#    'discount_date': False},
#   'tax_key': {'id': 65116},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-16',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01645 F1-CC/2024/01645',
#   'create_uid': [206, 'Mariana Araceli Carvajal Flores'],
#   'create_date': '2024-02-01 21:51:01',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:19',
#   'move_attachment_ids': [14374, 14373],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1578'},
#  {'id': 64409,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [16993, 'F1-CC/2024/01606 (PdV CSL/1599)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01606',
#   'parent_state': 'posted',
#   'date': '2024-02-01',
#   'invoice_date': '2024-02-01',
#   'ref': 'PdV CSL/1599',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01606',
#   'debit': 863.1,
#   'credit': 0.0,
#   'balance': 863.1,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 863.1,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19584, 19586],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-16',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 16993,
#    'date_maturity': '2024-02-16',
#    'discount_date': False},
#   'tax_key': {'id': 64409},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-16',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01606 (PdV CSL/1599) F1-CC/2024/01606',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-01 18:31:14',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:13',
#   'move_attachment_ids': [15820, 14127, 14126],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1599'},
#  {'id': 63067,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [16613, 'F1-CC/2024/01571 (PdV CSL/1569)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01571',
#   'parent_state': 'posted',
#   'date': '2024-02-01',
#   'invoice_date': '2024-02-01',
#   'ref': 'PdV CSL/1569',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01571',
#   'debit': 1101.44,
#   'credit': 0.0,
#   'balance': 1101.44,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 1101.44,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
# ...
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0733'},
#  {'id': 21536,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [5873, 'F1-CC/2024/00596 (PdV CSL/0594)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00596',
#   'parent_state': 'posted',
#   'date': '2024-01-12',
#   'invoice_date': '2024-01-12',
#   'ref': 'PdV CSL/0594',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00596',
#   'debit': 292.89,
#   'credit': 0.0,
#   'balance': 292.89,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 292.89,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19539],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-11',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 5873,
#    'date_maturity': '2024-02-11',
#    'discount_date': False},
#   'tax_key': {'id': 21536},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-11',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00596 (PdV CSL/0594) F1-CC/2024/00596',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-12 22:46:04',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:15:34',
#   'move_attachment_ids': [11884, 4728, 4727],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0594'},
#  {'id': 21157,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [5756, 'F1-CC/2024/00574 (PdV CSL/0572)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00574',
#   'parent_state': 'posted',
#   'date': '2024-01-12',
#   'invoice_date': '2024-01-12',
#   'ref': 'PdV CSL/0572',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00574',
#   'debit': 269.04,
#   'credit': 0.0,
#   'balance': 269.04,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 269.04,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19541],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-11',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 5756,
#    'date_maturity': '2024-02-11',
#    'discount_date': False},
#   'tax_key': {'id': 21157},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-11',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00574 (PdV CSL/0572) F1-CC/2024/00574',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-12 20:07:28',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:16:50',
#   'move_attachment_ids': [11883, 4632, 4631],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0572'},
#  {'id': 17385,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [4707, 'F1-CC/2024/00464 (PdV CSL/0461)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00464',
#   'parent_state': 'posted',
#   'date': '2024-01-11',
#   'invoice_date': '2024-01-11',
#   'ref': 'PdV CSL/0461',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00464',
#   'debit': 694.5,
#   'credit': 0.0,
#   'balance': 694.5,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 694.5,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19543],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-01-11',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 4707,
#    'date_maturity': '2024-01-11',
#    'discount_date': False},
#   'tax_key': {'id': 17385},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-01-11',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00464 (PdV CSL/0461) F1-CC/2024/00464',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-11 15:23:14',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:17:01',
#   'move_attachment_ids': [11882, 3938, 3937],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0461'},
#  {'id': 10867,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [2956, 'F1-CC/2024/00283 (PdV CSL/0279)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00283',
#   'parent_state': 'posted',
#   'date': '2024-01-08',
#   'invoice_date': '2024-01-08',
#   'ref': 'PdV CSL/0279',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00283',
#   'debit': 551.65,
#   'credit': 0.0,
#   'balance': 551.65,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 551.65,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19545],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-01-08',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 2956,
#    'date_maturity': '2024-01-08',
#    'discount_date': False},
#   'tax_key': {'id': 10867},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-01-08',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00283 (PdV CSL/0279) F1-CC/2024/00283',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-08 15:11:04',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:17:14',
#   'move_attachment_ids': [11873, 2581, 2580],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0279'},
#  {'id': 581,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [190, 'F1-CC/2024/00012 (Shop/0025)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00012',
#   'parent_state': 'posted',
#   'date': '2024-01-02',
#   'invoice_date': '2024-01-02',
#   'ref': 'Shop/0025',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00012',
#   'debit': 430.48,
#   'credit': 0.0,
#   'balance': 430.48,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 430.48,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19547],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-01-02',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 190,
#    'date_maturity': '2024-01-02',
#    'discount_date': False},
#   'tax_key': {'id': 581},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-01-02',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00012 (Shop/0025) F1-CC/2024/00012',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-02 18:02:42',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:17:33',
#   'move_attachment_ids': [11872, 781, 780, 779],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'Shop/0025'}]
