# %%
import xmlrpc.client
import os

api_url = os.environ.get('ODOO_URL_API')
# api_db = os.environ.get('ODOO_DB_API')
api_db = os.environ.get('ODOO_DB_PRUEBA_API')
api_username = os.environ.get('ODOO_USERNAME_API')
api_clave = os.environ.get('ODOO_CLAVE_API')

common = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/common')
uid = common.authenticate(api_db, api_username, api_clave, {})
models = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/object')

# %%
# ids = models.execute_kw(api_db, uid, api_clave, 'account.move', 'search', [[("pos_order_ids", "=", 13559)]])
wep = models.execute_kw(api_db, uid, api_clave, 'account.move', 'read', [[60003]])
wep
# Out:
# [{'id': 64097,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'F2-CC/2024/',
#   'sequence_number': 7464,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'access_url': '/my/invoices/64097',
#   'access_token': 'bdfa9ec3-9608-46e6-8d4d-69a87204a474',
#   'access_warning': '',
#   'message_is_follower': False,
#   'message_follower_ids': [176748, 176749],
#   'message_partner_ids': [216, 13024],
#   'message_ids': [339602, 339593, 339592, 339589, 339588],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 2,
#   'rating_ids': [],
#   'website_message_ids': [339593],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': [55672, 'F2-CC_2024_07464_proforma.pdf'],
#   'name': 'F2-CC/2024/07464',
#   'ref': 'PdV SJC/7607',
#   'date': '2024-04-18',
#   'state': 'posted',
#   'move_type': 'out_invoice',
#   'is_storno': False,
#   'journal_id': [90, 'Facturas de cliente A2'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [240955, 240956, 240957, 240958],
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [64101, 64099],
#   'always_tax_exigible': False,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [10, 90, 112, 113],
#   'highest_name': 'F2-CC/2024/07463',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Factura',
#   'country_code': 'MX',
#   'attachment_ids': [55671, 55670],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-04-18","journal_id":"90","line_240955_account_id":"85","line_240955_credit":"211.08","line_240955_debit":"0.00","line_240955_name":"[1933] Estopa (Bolsa 1Kg) \\"Ardilla\\" *1933*","line_240955_partner_id":"13024","line_240956_account_id":"85","line_240956_credit":"546.56","line_240956_debit":"0.00","line_240956_name":"[35396] Cerrojo Ph Llave-Mar #260-5 LA #81215 *35396*","line_240956_partner_id":"13024","line_240957_account_id":"73","line_240957_credit":"121.22","line_240957_debit":"0.00","line_240957_name":"16%","line_240957_partner_id":"13024","line_240958_account_id":"49","line_240958_credit":"0.00","line_240958_debit":"878.86","line_240958_name":"F2-CC/2024/07464","line_240958_partner_id":"13024","name":"F2-CC/2024/07464"}',
#   'invoice_line_ids': [240955, 240956],
#   'invoice_date': '2024-04-18',
#   'invoice_date_due': '2024-04-18',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'partner_id': [13024, 'CLAUDIA ANTONIETA PADILLA CANALES'],
#   'commercial_partner_id': [13024, 'CLAUDIA ANTONIETA PADILLA CANALES'],
#   'partner_shipping_id': [13024, 'CLAUDIA ANTONIETA PADILLA CANALES'],
#   'partner_bank_id': False,
#   'fiscal_position_id': False,
#   'payment_reference': 'F2-CC/2024/07464',
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': {'title': 'Menos pagos',
#    'outstanding': False,
#    'content': [{'name': False,
#      'journal_name': 'Punto De Venta A2',
#      'company_name': False,
#      'amount': 269.0,
#      'currency_id': 32,
#      'date': '2024-04-18',
#      'partial_id': 54382,
#      'account_payment_id': False,
#      'payment_method_name': False,
#      'move_id': 64098,
#      'ref': 'PV1A2/2024/04/1679 (Pago de factura para PdV SJC/7607 (F2-CC/2024/07464) utilizando Efectivo A2)',
#      'is_exchange': False,
#      'amount_company_currency': '$\xa0269.00',
#      'amount_foreign_currency': False,
#      'pos_payment_name': 'Efectivo A2'},
#     {'name': '',
#      'journal_name': 'Facturas de cliente A2',
#      'company_name': False,
#      'amount': 609.86,
#      'currency_id': 32,
#      'date': '2024-04-18',
#      'partial_id': 54384,
#      'account_payment_id': False,
#      'payment_method_name': False,
#      'move_id': 64096,
#      'ref': 'RF2-CC/2024/00063 (Reversión de: F2-CC/2024/07405)',
#      'is_exchange': False,
#      'amount_company_currency': '$\xa0609.86',
#      'amount_foreign_currency': False,
#      'pos_payment_name': False}]},
#   'company_currency_id': [32, 'MXN'],
#   'currency_id': [32, 'MXN'],
#   'direction_sign': -1,
#   'amount_untaxed': 757.64,
#   'amount_tax': 121.22,
#   'amount_total': 878.86,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 757.64,
#   'amount_tax_signed': 121.22,
#   'amount_total_signed': 878.86,
#   'amount_total_in_currency_signed': 878.86,
#   'amount_residual_signed': 0.0,
#   'tax_totals': {'amount_untaxed': 757.64,
#    'amount_total': 878.86,
#    'formatted_amount_total': '$\xa0878.86',
#    'formatted_amount_untaxed': '$\xa0757.64',
#    'groups_by_subtotal': {'Importe sin impuestos': [{'group_key': 3,
#       'tax_group_id': 3,
#       'tax_group_name': 'VAT 16%',
#       'tax_group_amount': 121.22,
#       'tax_group_base_amount': 757.6400000000001,
#       'formatted_tax_group_amount': '$\xa0121.22',
#       'formatted_tax_group_base_amount': '$\xa0757.64'}]},
#    'subtotals': [{'name': 'Importe sin impuestos',
#      'amount': 757.6400000000001,
#      'formatted_amount': '$\xa0757.64'}],
#    'subtotals_order': ['Importe sin impuestos'],
#    'display_tax_base': False},
#   'payment_state': 'reversed',
#   'amount_total_words': 'OCHOCIENTOS SETENTA Y OCHO PESOS 86/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'CLAUDIA ANTONIETA PADILLA CANALES',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': [215, 'Gretel Gómez Alcázar'],
#   'user_id': [215, 'Gretel Gómez Alcázar'],
#   'invoice_origin': 'PdV SJC/7607',
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': 'sale',
#   'bank_partner_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 878.86,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'display_name': 'F2-CC/2024/07464 (PdV SJC/7607)',
#   'create_uid': [215, 'Gretel Gómez Alcázar'],
#   'create_date': '2024-04-18 15:13:02',
#   'write_uid': [215, 'Gretel Gómez Alcázar'],
#   'write_date': '2024-04-18 15:14:04',
#   'payment_ids': [],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [16267],
#   'l10n_mx_edi_payment_document_ids': [16267],
#   'l10n_mx_edi_document_ids': [16267],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-04-18 08:13:03',
#   'l10n_mx_edi_usage': 'S01',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [22, 'Por definir'],
#   'l10n_mx_edi_payment_policy': 'PUE',
#   'l10n_mx_edi_cfdi_to_public': True,
#   'pos_order_ids': [13558],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [6, 'A2 SJC'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False}]

# %%
account_move_line_fields = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'fields_get', [])

list_fields = list(account_move_line_fields.keys())
list_fields.remove('compute_all_tax')

# %%
ids2 = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'search', [['&', ("move_id", "=", 64115), ("partner_id", "=", 15408)]])
wep2 = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'read', [ids2], {'fields': list_fields})
wep2
# Out:
# [{'id': 241026,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [64115, 'PV1A2/2024/04/1680 (POS/00195)'],
#   'journal_id': [92, 'Punto De Venta A2'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'PV1A2/2024/04/1680',
#   'parent_state': 'posted',
#   'date': '2024-04-20',
#   'invoice_date': False,
#   'ref': 'POS/00195',
#   'is_storno': False,
#   'sequence': 100,
#   'move_type': 'entry',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'POS/00195 - Crédito del cliente',
#   'debit': 0.0,
#   'credit': 5000.0,
#   'balance': -5000.0,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': -5000.0,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [54556, 54558, 54560, 54562, 54564, 54566],
#   'matched_credit_ids': [],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'product',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 1.0,
#   'date_maturity': False,
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': False,
#   'tax_key': {'id': 241026},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': False,
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'PV1A2/2024/04/1680 (POS/00195) POS/00195 - Crédito del cliente',
#   'create_uid': [2, 'Lic. Costich'],
#   'create_date': '2024-04-20 19:17:50',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:41',
#   'move_attachment_ids': [],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': False}]

# %%
ids3 = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'search', [['&', ("move_type", "=", "out_invoice"), ("matching_number", "=", "P19535")]])
wep3 = models.execute_kw(api_db, uid, api_clave, 'account.move.line', 'read', [ids3], {'fields': list_fields})
wep3
# Out:
# [{'id': 212734,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [56778, 'F1-CC/2024/05053 (PdV CSL/5009)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/05053',
#   'parent_state': 'posted',
#   'date': '2024-04-08',
#   'invoice_date': '2024-04-08',
#   'ref': 'PdV CSL/5009',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/05053',
#   'debit': 78.88,
#   'credit': 0.0,
#   'balance': 78.88,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 78.88,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54564],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-08',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 56778,
#    'date_maturity': '2024-05-08',
#    'discount_date': False},
#   'tax_key': {'id': 212734},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-08',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/05053 (PdV CSL/5009) F1-CC/2024/05053',
#   'create_uid': [242, 'Maria Guadalupe Camacho Escalante'],
#   'create_date': '2024-04-08 15:15:11',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:22',
#   'move_attachment_ids': [54816, 49509, 49508],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/5009'},
#  {'id': 174576,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [46571, 'F1-CC/2024/04239 (PdV CSL/4189)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/04239',
#   'parent_state': 'posted',
#   'date': '2024-03-21',
#   'invoice_date': '2024-03-21',
#   'ref': 'PdV CSL/4189',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/04239',
#   'debit': 536.04,
#   'credit': 0.0,
#   'balance': 536.04,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 536.04,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54562],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-05',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 46571,
#    'date_maturity': '2024-05-05',
#    'discount_date': False},
#   'tax_key': {'id': 174576},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-05',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/04239 (PdV CSL/4189) F1-CC/2024/04239',
#   'create_uid': [212, 'Reyna Arriaga Flores'],
#   'create_date': '2024-03-21 23:31:59',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:14',
#   'move_attachment_ids': [40469, 40176, 40175],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/4189'},
#  {'id': 173566,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [46272, 'F1-CC/2024/04198 (PdV CSL/4148)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/04198',
#   'parent_state': 'posted',
#   'date': '2024-03-21',
#   'invoice_date': '2024-03-21',
#   'ref': 'PdV CSL/4148',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/04198',
#   'debit': 1733.37,
#   'credit': 0.0,
#   'balance': 1733.37,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 1733.37,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54558],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-05',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 46272,
#    'date_maturity': '2024-05-05',
#    'discount_date': False},
#   'tax_key': {'id': 173566},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-05',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/04198 (PdV CSL/4148) F1-CC/2024/04198',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-21 18:18:06',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:39:36',
#   'move_attachment_ids': [40470, 39818, 39817],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/4148'},
#  {'id': 170904,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [45604, 'F1-CC/2024/04123 (PdV CSL/4073)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/04123',
#   'parent_state': 'posted',
#   'date': '2024-03-20',
#   'invoice_date': '2024-03-20',
#   'ref': 'PdV CSL/4073',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/04123',
#   'debit': 390.32,
#   'credit': 0.0,
#   'balance': 390.32,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 390.32,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54560],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-04',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 45604,
#    'date_maturity': '2024-05-04',
#    'discount_date': False},
#   'tax_key': {'id': 170904},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-04',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/04123 (PdV CSL/4073) F1-CC/2024/04123',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-20 18:43:58',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:03',
#   'move_attachment_ids': [40467, 39177, 39176],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/4073'},
#  {'id': 168862,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [45067, 'F1-CC/2024/04072 (PdV CSL/4022)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/04072',
#   'parent_state': 'posted',
#   'date': '2024-03-19',
#   'invoice_date': '2024-03-19',
#   'ref': 'PdV CSL/4022',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/04072',
#   'debit': 365.55,
#   'credit': 0.0,
#   'balance': 365.55,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 365.55,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [54556],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-03',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 45067,
#    'date_maturity': '2024-05-03',
#    'discount_date': False},
#   'tax_key': {'id': 168862},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-03',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/04072 (PdV CSL/4022) F1-CC/2024/04072',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-19 21:18:14',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:39:24',
#   'move_attachment_ids': [40461, 38690, 38689],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/4022'},
#  {'id': 165540,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [44148, 'F1-CC/2024/03971 (PdV CSL/3918)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/03971',
#   'parent_state': 'posted',
#   'date': '2024-03-18',
#   'invoice_date': '2024-03-18',
#   'ref': 'PdV CSL/3918',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/03971',
#   'debit': 15263.43,
#   'credit': 0.0,
#   'balance': 15263.43,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 15263.43,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 10978.86,
#   'amount_residual_currency': 10978.86,
#   'reconciled': False,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [50764, 54566],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-05-02',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 44148,
#    'date_maturity': '2024-05-02',
#    'discount_date': False},
#   'tax_key': {'id': 165540},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-05-02',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/03971 (PdV CSL/3918) F1-CC/2024/03971',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-18 15:13:57',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 19:40:41',
#   'move_attachment_ids': [39528, 37899, 37897],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/3918'},
#  {'id': 87275,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [23359, 'F1-CC/2024/02164 (PdV CSL/2089)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/02164',
#   'parent_state': 'posted',
#   'date': '2024-02-12',
#   'invoice_date': '2024-02-12',
#   'ref': 'PdV CSL/2089',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/02164',
#   'debit': 136.91,
#   'credit': 0.0,
#   'balance': 136.91,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 136.91,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19602],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-27',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 23359,
#    'date_maturity': '2024-02-27',
#    'discount_date': False},
#   'tax_key': {'id': 87275},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-27',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/02164 (PdV CSL/2089) F1-CC/2024/02164',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-12 15:06:58',
#   'write_uid': [206, 'Mariana Araceli Carvajal Flores'],
#   'write_date': '2024-02-13 01:10:19',
#   'move_attachment_ids': [20334, 19643, 19642],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/2089'},
#  {'id': 85103,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [22743, 'F1-CC/2024/02125 (PdV CSL/2044)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/02125',
#   'parent_state': 'posted',
#   'date': '2024-02-10',
#   'invoice_date': '2024-02-10',
#   'ref': 'PdV CSL/2044',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/02125',
#   'debit': 380.33,
#   'credit': 0.0,
#   'balance': 380.33,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 380.33,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19600],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-25',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 22743,
#    'date_maturity': '2024-02-25',
#    'discount_date': False},
#   'tax_key': {'id': 85103},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-25',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/02125 (PdV CSL/2044) F1-CC/2024/02125',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-10 16:14:05',
#   'write_uid': [206, 'Mariana Araceli Carvajal Flores'],
#   'write_date': '2024-02-12 18:46:45',
#   'move_attachment_ids': [19859, 19084, 19083],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/2044'},
#  {'id': 82561,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [22014, 'F1-CC/2024/02065 (PdV CSL/1984)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/02065',
#   'parent_state': 'posted',
#   'date': '2024-02-09',
#   'invoice_date': '2024-02-09',
#   'ref': 'PdV CSL/1984',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/02065',
#   'debit': 3764.56,
#   'credit': 0.0,
#   'balance': 3764.56,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 3764.56,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19598],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-24',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 22014,
#    'date_maturity': '2024-02-24',
#    'discount_date': False},
#   'tax_key': {'id': 82561},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-24',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/02065 (PdV CSL/1984) F1-CC/2024/02065',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-09 15:35:06',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:54',
#   'move_attachment_ids': [18557, 18437, 18436],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1984'},
#  {'id': 75579,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [20035, 'F1-CC/2024/01919 (PdV CSL/1837)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01919',
#   'parent_state': 'posted',
#   'date': '2024-02-06',
#   'invoice_date': '2024-02-06',
#   'ref': 'PdV CSL/1837',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01919',
#   'debit': 625.81,
#   'credit': 0.0,
#   'balance': 625.81,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 625.81,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19596],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-21',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 20035,
#    'date_maturity': '2024-02-21',
#    'discount_date': False},
#   'tax_key': {'id': 75579},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-21',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01919 (PdV CSL/1837) F1-CC/2024/01919',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-06 18:27:08',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:47',
#   'move_attachment_ids': [17215, 17043, 16529, 16528],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1837'},
#  {'id': 72867,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [19245, 'F1-CC/2024/01832 (PdV CSL/1750)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01832',
#   'parent_state': 'posted',
#   'date': '2024-02-05',
#   'invoice_date': '2024-02-05',
#   'ref': 'PdV CSL/1750',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01832',
#   'debit': 242.29,
#   'credit': 0.0,
#   'balance': 242.29,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 242.29,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19594],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-20',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 19245,
#    'date_maturity': '2024-02-20',
#    'discount_date': False},
#   'tax_key': {'id': 72867},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-20',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01832 (PdV CSL/1750) F1-CC/2024/01832',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-05 15:13:59',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:40',
#   'move_attachment_ids': [17096, 17042, 15925, 15924],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1750'},
#  {'id': 70249,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [18525, 'F1-CC/2024/01750 (PdV CSL/1695)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01750',
#   'parent_state': 'posted',
#   'date': '2024-02-03',
#   'invoice_date': '2024-02-03',
#   'ref': 'PdV CSL/1695',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01750',
#   'debit': 246.63,
#   'credit': 0.0,
#   'balance': 246.63,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 246.63,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19590],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-18',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 18525,
#    'date_maturity': '2024-02-18',
#    'discount_date': False},
#   'tax_key': {'id': 70249},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-18',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01750 (PdV CSL/1695) F1-CC/2024/01750',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-03 15:42:49',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:24',
#   'move_attachment_ids': [15341, 15340],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1695'},
#  {'id': 70238,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [18521, 'F1-CC/2024/01749 (PdV CSL/1694)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01749',
#   'parent_state': 'posted',
#   'date': '2024-02-03',
#   'invoice_date': '2024-02-03',
#   'ref': 'PdV CSL/1694',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01749',
#   'debit': 1609.52,
#   'credit': 0.0,
#   'balance': 1609.52,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 1609.52,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19592],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-18',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 18521,
#    'date_maturity': '2024-02-18',
#    'discount_date': False},
#   'tax_key': {'id': 70238},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-18',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01749 (PdV CSL/1694) F1-CC/2024/01749',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-03 15:30:45',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:33',
#   'move_attachment_ids': [15333, 15332],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1694'},
#  {'id': 65116,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [17191, 'F1-CC/2024/01645'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01645',
#   'parent_state': 'posted',
#   'date': '2024-02-01',
#   'invoice_date': '2024-02-01',
#   'ref': False,
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01645',
#   'debit': 576.6,
#   'credit': 0.0,
#   'balance': 576.6,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 576.6,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19588],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-16',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 17191,
#    'date_maturity': '2024-02-16',
#    'discount_date': False},
#   'tax_key': {'id': 65116},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-16',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01645 F1-CC/2024/01645',
#   'create_uid': [206, 'Mariana Araceli Carvajal Flores'],
#   'create_date': '2024-02-01 21:51:01',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:19',
#   'move_attachment_ids': [14374, 14373],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1578'},
#  {'id': 64409,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [16993, 'F1-CC/2024/01606 (PdV CSL/1599)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01606',
#   'parent_state': 'posted',
#   'date': '2024-02-01',
#   'invoice_date': '2024-02-01',
#   'ref': 'PdV CSL/1599',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01606',
#   'debit': 863.1,
#   'credit': 0.0,
#   'balance': 863.1,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 863.1,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19584, 19586],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-16',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 16993,
#    'date_maturity': '2024-02-16',
#    'discount_date': False},
#   'tax_key': {'id': 64409},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-16',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/01606 (PdV CSL/1599) F1-CC/2024/01606',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-01 18:31:14',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:25:13',
#   'move_attachment_ids': [15820, 14127, 14126],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/1599'},
#  {'id': 63067,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [16613, 'F1-CC/2024/01571 (PdV CSL/1569)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/01571',
#   'parent_state': 'posted',
#   'date': '2024-02-01',
#   'invoice_date': '2024-02-01',
#   'ref': 'PdV CSL/1569',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/01571',
#   'debit': 1101.44,
#   'credit': 0.0,
#   'balance': 1101.44,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 1101.44,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
# ...
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0733'},
#  {'id': 21536,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [5873, 'F1-CC/2024/00596 (PdV CSL/0594)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00596',
#   'parent_state': 'posted',
#   'date': '2024-01-12',
#   'invoice_date': '2024-01-12',
#   'ref': 'PdV CSL/0594',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00596',
#   'debit': 292.89,
#   'credit': 0.0,
#   'balance': 292.89,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 292.89,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19539],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-11',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 5873,
#    'date_maturity': '2024-02-11',
#    'discount_date': False},
#   'tax_key': {'id': 21536},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-11',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00596 (PdV CSL/0594) F1-CC/2024/00596',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-12 22:46:04',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:15:34',
#   'move_attachment_ids': [11884, 4728, 4727],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0594'},
#  {'id': 21157,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [5756, 'F1-CC/2024/00574 (PdV CSL/0572)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00574',
#   'parent_state': 'posted',
#   'date': '2024-01-12',
#   'invoice_date': '2024-01-12',
#   'ref': 'PdV CSL/0572',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00574',
#   'debit': 269.04,
#   'credit': 0.0,
#   'balance': 269.04,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 269.04,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19541],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-02-11',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 5756,
#    'date_maturity': '2024-02-11',
#    'discount_date': False},
#   'tax_key': {'id': 21157},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-02-11',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00574 (PdV CSL/0572) F1-CC/2024/00574',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-12 20:07:28',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:16:50',
#   'move_attachment_ids': [11883, 4632, 4631],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0572'},
#  {'id': 17385,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [4707, 'F1-CC/2024/00464 (PdV CSL/0461)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00464',
#   'parent_state': 'posted',
#   'date': '2024-01-11',
#   'invoice_date': '2024-01-11',
#   'ref': 'PdV CSL/0461',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00464',
#   'debit': 694.5,
#   'credit': 0.0,
#   'balance': 694.5,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 694.5,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19543],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-01-11',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 4707,
#    'date_maturity': '2024-01-11',
#    'discount_date': False},
#   'tax_key': {'id': 17385},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-01-11',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00464 (PdV CSL/0461) F1-CC/2024/00464',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-11 15:23:14',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:17:01',
#   'move_attachment_ids': [11882, 3938, 3937],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0461'},
#  {'id': 10867,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [2956, 'F1-CC/2024/00283 (PdV CSL/0279)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00283',
#   'parent_state': 'posted',
#   'date': '2024-01-08',
#   'invoice_date': '2024-01-08',
#   'ref': 'PdV CSL/0279',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00283',
#   'debit': 551.65,
#   'credit': 0.0,
#   'balance': 551.65,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 551.65,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19545],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-01-08',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 2956,
#    'date_maturity': '2024-01-08',
#    'discount_date': False},
#   'tax_key': {'id': 10867},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-01-08',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00283 (PdV CSL/0279) F1-CC/2024/00283',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-08 15:11:04',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:17:14',
#   'move_attachment_ids': [11873, 2581, 2580],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'PdV CSL/0279'},
#  {'id': 581,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'move_id': [190, 'F1-CC/2024/00012 (Shop/0025)'],
#   'journal_id': [10, 'Facturas de cliente A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'company_currency_id': [32, 'MXN'],
#   'move_name': 'F1-CC/2024/00012',
#   'parent_state': 'posted',
#   'date': '2024-01-02',
#   'invoice_date': '2024-01-02',
#   'ref': 'Shop/0025',
#   'is_storno': False,
#   'sequence': 12000,
#   'move_type': 'out_invoice',
#   'account_id': [49, '105.01.01 Domestic customers'],
#   'name': 'F1-CC/2024/00012',
#   'debit': 430.48,
#   'credit': 0.0,
#   'balance': 430.48,
#   'cumulated_balance': 0.0,
#   'currency_rate': 1.0,
#   'amount_currency': 430.48,
#   'currency_id': [32, 'MXN'],
#   'is_same_currency': True,
#   'partner_id': [15408, 'GUADALUPE (SR.PINACHO)'],
#   'reconcile_model_id': False,
#   'payment_id': False,
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_ids': [],
#   'group_tax_id': False,
#   'tax_line_id': False,
#   'tax_group_id': False,
#   'tax_base_amount': 0.0,
#   'tax_repartition_line_id': False,
#   'tax_tag_ids': [],
#   'tax_tag_invert': False,
#   'amount_residual': 0.0,
#   'amount_residual_currency': 0.0,
#   'reconciled': True,
#   'full_reconcile_id': False,
#   'matched_debit_ids': [],
#   'matched_credit_ids': [19547],
#   'matching_number': 'P19535',
#   'is_account_reconcile': True,
#   'account_type': 'asset_receivable',
#   'account_internal_group': 'asset',
#   'account_root_id': [49048, '10'],
#   'display_type': 'payment_term',
#   'product_id': False,
#   'product_uom_id': False,
#   'product_uom_category_id': False,
#   'quantity': 0.0,
#   'date_maturity': '2024-01-02',
#   'price_unit': 0.0,
#   'price_subtotal': 0.0,
#   'price_total': 0.0,
#   'discount': 0.0,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'term_key': {'move_id': 190,
#    'date_maturity': '2024-01-02',
#    'discount_date': False},
#   'tax_key': {'id': 581},
#   'compute_all_tax_dirty': True,
#   'epd_key': False,
#   'epd_needed': False,
#   'epd_dirty': True,
#   'discount_allocation_key': False,
#   'discount_allocation_needed': False,
#   'discount_allocation_dirty': True,
#   'analytic_line_ids': [],
#   'discount_date': False,
#   'discount_amount_currency': 0.0,
#   'discount_balance': 0.0,
#   'payment_date': '2024-01-02',
#   'blocked': False,
#   'is_refund': False,
#   'display_name': 'F1-CC/2024/00012 (Shop/0025) F1-CC/2024/00012',
#   'create_uid': [226, 'Erika Guerrero Leal'],
#   'create_date': '2024-01-02 18:02:42',
#   'write_uid': [236, 'Bianca Sánchez Valenciano'],
#   'write_date': '2024-02-12 16:17:33',
#   'move_attachment_ids': [11872, 781, 780, 779],
#   'deferred_start_date': False,
#   'deferred_end_date': False,
#   'has_deferred_moves': False,
#   'purchase_line_id': False,
#   'purchase_order_id': False,
#   'stock_valuation_layer_ids': [],
#   'cogs_origin_id': False,
#   'expected_pay_date': False,
#   'is_downpayment': False,
#   'sale_line_ids': [],
#   'asset_ids': [],
#   'non_deductible_tax_value': 0.0,
#   'followup_line_id': False,
#   'last_followup_date': False,
#   'next_action_date': False,
#   'invoice_origin': 'Shop/0025'}]
