# %%
import xmlrpc.client
import os

api_url = os.environ.get('ODOO_URL_API')
# api_db = os.environ.get('ODOO_DB_API')
api_db = os.environ.get('ODOO_DB_PRUEBA_API')
api_username = os.environ.get('ODOO_USERNAME_API')
api_clave = os.environ.get('ODOO_CLAVE_API')

common = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/common')
uid = common.authenticate(api_db, api_username, api_clave, {})
models = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/object')

# %%
ids = models.execute_kw(api_db, uid, api_clave, 'account.payment', 'search', [[("date", ">=", "2024-04-22")]])
wep = models.execute_kw(api_db, uid, api_clave, 'account.payment', 'read', [ids])
wep
# Out:
# [{'id': 1046,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [176839],
#   'message_partner_ids': [3],
#   'message_ids': [339735, 339733, 339732],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [64165, 'PBS1CC/2024/00203'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [5, 'Manual'],
#   'available_payment_method_line_ids': [5],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 200.0,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': [15371, 'ANGEL MALDONADO TORRES'],
#   'outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [49, '105.01.01 Domestic customers'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [63193],
#   'reconciled_invoices_count': 1,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': True,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 200.0,
#   'amount_company_currency_signed': 200.0,
#   'display_name': 'PBS1CC/2024/00203',
#   'create_uid': [2, 'Lic. Costich'],
#   'create_date': '2024-04-20 20:33:14',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-20 20:33:44',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': False,
#   'force_outstanding_account_id': False,
#   'pos_session_id': False,
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PBS1CC/2024/',
#   'sequence_number': 203,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PBS1CC/2024/00203',
#   'ref': False,
#   'date': '2024-05-01',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [15, 'Banco Sant92000702524'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [241210, 241211],
#   'payment_id': [1046, 'PBS1CC/2024/00203'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PBS1CC/2024/00204',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-05-01","journal_id":"15","line_241210_account_id":"98","line_241210_credit":"0.00","line_241210_debit":"200.00","line_241210_name":"Pago de cliente $\\u00a0200.00 - ANGEL MALDONADO TORRES - 01/05/2024","line_241210_partner_id":"15371","line_241211_account_id":"49","line_241211_credit":"200.00","line_241211_debit":"0.00","line_241211_name":"Pago de cliente $\\u00a0200.00 - ANGEL MALDONADO TORRES - 01/05/2024","line_241211_partner_id":"15371","name":"PBS1CC/2024/00203"}',
#   'invoice_line_ids': [241210, 241211],
#   'invoice_date': False,
#   'invoice_date_due': '2024-04-20',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'commercial_partner_id': [15371, 'ANGEL MALDONADO TORRES'],
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 200.0,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 200.0,
#   'amount_total_in_currency_signed': 200.0,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'DOSCIENTOS PESOS 00/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'ANGEL MALDONADO TORRES',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [15371, 'ANGEL MALDONADO TORRES'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 25425.88,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [1046],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-04-20 13:33:14',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [8, 'CE A2'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 1047,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [176862],
#   'message_partner_ids': [3],
#   'message_ids': [339769],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [64185, 'PE-VS/2024/00007 (F1-VS/2024/01232)'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [14, 'Manual'],
#   'available_payment_method_line_ids': [14],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 580.0,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': [413, 'Emilio Costich Lopez'],
#   'outstanding_account_id': [210, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [161, '105.01.01 VyS Clientes nacionales'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [64184],
#   'reconciled_invoices_count': 1,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': False,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 580.0,
#   'amount_company_currency_signed': 580.0,
#   'display_name': 'PE-VS/2024/00007',
#   'create_uid': [2, 'Lic. Costich'],
#   'create_date': '2024-04-22 21:18:01',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 21:18:01',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': False,
#   'force_outstanding_account_id': False,
#   'pos_session_id': False,
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PE-VS/2024/',
#   'sequence_number': 7,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PE-VS/2024/00007',
#   'ref': 'F1-VS/2024/01232',
#   'date': '2024-04-22',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [36, 'Efectivo'],
#   'company_id': [2, 'La Casa Del Carpintero Ventas y Soluciones'],
#   'line_ids': [241281, 241282],
#   'payment_id': [1047, 'PE-VS/2024/00007'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [32, 37, 33, 34, 38, 39],
#   'highest_name': 'PE-VS/2024/00006',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"2","date":"2024-04-22","journal_id":"36","line_241281_account_id":"210","line_241281_credit":"0.00","line_241281_debit":"580.00","line_241281_name":"Pago de cliente $\\u00a0580.00 - Emilio Costich Lopez - 22/04/2024","line_241281_partner_id":"413","line_241282_account_id":"161","line_241282_credit":"580.00","line_241282_debit":"0.00","line_241282_name":"Pago de cliente $\\u00a0580.00 - Emilio Costich Lopez - 22/04/2024","line_241282_partner_id":"413","name":"PE-VS/2024/00007"}',
#   'invoice_line_ids': [241281, 241282],
#   'invoice_date': False,
#   'invoice_date_due': '2024-04-22',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'commercial_partner_id': [413, 'Emilio Costich Lopez'],
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 580.0,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 580.0,
#   'amount_total_in_currency_signed': 580.0,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'QUINIENTOS OCHENTA PESOS 00/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'Emilio Costich Lopez',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [413, 'Emilio Costich Lopez'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': -837.09,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [1047],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-04-22 14:18:01',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [1, 'Efectivo'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [8, 'CE A2'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 1048,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [176871],
#   'message_partner_ids': [3],
#   'message_ids': [339780],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [64188, 'PBS1CC/2024/00204 (F1-CC/2024/05709)'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [5, 'Manual'],
#   'available_payment_method_line_ids': [5],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 533.0,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': [413, 'Emilio Costich Lopez'],
#   'outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [49, '105.01.01 Domestic customers'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [64187],
#   'reconciled_invoices_count': 1,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': True,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 533.0,
#   'amount_company_currency_signed': 533.0,
#   'display_name': 'PBS1CC/2024/00204',
#   'create_uid': [2, 'Lic. Costich'],
#   'create_date': '2024-04-22 21:18:53',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-22 21:18:53',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': False,
#   'force_outstanding_account_id': False,
#   'pos_session_id': False,
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PBS1CC/2024/',
#   'sequence_number': 204,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PBS1CC/2024/00204',
#   'ref': 'F1-CC/2024/05709',
#   'date': '2024-04-22',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [15, 'Banco Sant92000702524'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [241290, 241291],
#   'payment_id': [1048, 'PBS1CC/2024/00204'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PBS1CC/2024/00203',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-04-22","journal_id":"15","line_241290_account_id":"98","line_241290_credit":"0.00","line_241290_debit":"533.00","line_241290_name":"Pago de cliente $\\u00a0533.00 - Emilio Costich Lopez - 22/04/2024","line_241290_partner_id":"413","line_241291_account_id":"49","line_241291_credit":"533.00","line_241291_debit":"0.00","line_241291_name":"Pago de cliente $\\u00a0533.00 - Emilio Costich Lopez - 22/04/2024","line_241291_partner_id":"413","name":"PBS1CC/2024/00204"}',
#   'invoice_line_ids': [241290, 241291],
#   'invoice_date': False,
#   'invoice_date_due': '2024-04-22',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_per_line',
#   'commercial_partner_id': [413, 'Emilio Costich Lopez'],
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 533.0,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 533.0,
#   'amount_total_in_currency_signed': 533.0,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'QUINIENTOS TREINTA Y TRES PESOS 00/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': 'Emilio Costich Lopez',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': [413, 'Emilio Costich Lopez'],
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': -837.09,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [1048],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-04-22 14:18:54',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [1, 'Efectivo'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [8, 'CE A2'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False}]
