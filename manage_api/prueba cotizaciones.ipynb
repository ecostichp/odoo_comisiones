# %%
import xmlrpc.client
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

api_url = os.environ.get('ODOO_URL_API')
api_db = os.environ.get('ODOO_DB_API')
api_username = os.environ.get('ODOO_USERNAME_API')
api_clave = os.environ.get('ODOO_CLAVE_API')

common = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/common')
uid = common.authenticate(api_db, api_username, api_clave, {})
models = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/object')

# %%
ids = models.execute_kw(api_db, uid, api_clave, 'sale.order', 'search', [[("name", "=", "S10640")]])
wep = models.execute_kw(api_db, uid, api_clave, 'sale.order', 'read', [ids])
wep
# Out:
# [{'id': 10640,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [96846, 96847],
#   'message_partner_ids': [223, 14807],
#   'message_ids': [185276, 185273],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'access_url': '/my/orders/10640',
#   'access_token': False,
# ...

# %%
ids2 = wep[0]['order_line']
wep2 = models.execute_kw(api_db, uid, api_clave, 'sale.order.line', 'read', [ids2])
wep2
# Out:
# [{'id': 29031,
#   'analytic_distribution': False,
#   'analytic_distribution_search': False,
#   'analytic_precision': 2,
#   'order_id': [10640, 'S10640'],
#   'sequence': 10,
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'currency_id': [32, 'MXN'],
#   'order_partner_id': [14807, 'PROMOTORA LOS ANGELES CABOS'],
#   'salesman_id': [222, 'Yolanda Alejandra Rodriguez González'],
#   'state': 'sale',
#   'tax_country_id': [156, 'Mexico'],
#   'display_type': False,
#   'is_downpayment': False,
#   'is_expense': False,
#   'product_id': [12561,
#    '[12386] Faja C/Tirantes y 3er Cint Mediana#14216 *12386*'],
#   'product_template_id': [12561,
#    '[12386] Faja C/Tirantes y 3er Cint Mediana#14216 *12386*'],
#   'product_uom_category_id': [1, 'Unit'],
#   'product_custom_attribute_value_ids': [],
#   'product_no_variant_attribute_value_ids': [],
#   'name': '[12386] Faja C/Tirantes y 3er Cint Mediana#14216 *12386*',
#   'product_uom_qty': 1.0,
# ...

# %%
for i in wep:
    print(i['name'])
# Out:
# S10640

# %%
for i in wep2:
    print(i['name'])
# Out:
# [12386] Faja C/Tirantes y 3er Cint Mediana#14216 *12386*
