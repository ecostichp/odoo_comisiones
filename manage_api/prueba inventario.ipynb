# %%
import xmlrpc.client
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

api_url = os.environ.get('ODOO_URL_API')
# api_db = os.environ.get('ODOO_DB_API')
api_db = os.environ.get('ODOO_DB_PRUEBA_API')
api_username = os.environ.get('ODOO_USERNAME_API')
api_clave = os.environ.get('ODOO_CLAVE_API')

common = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/common')
uid = common.authenticate(api_db, api_username, api_clave, {})
models = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/object')

# %%
wep = models.execute_kw(api_db, uid, api_clave, 'product.template', 'read', [[27326]])
wep
# Out:
# [{'id': 27326,
#   'image_1920': False,
#   'image_1024': False,
#   'image_512': False,
#   'image_256': False,
#   'image_128': False,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [],
#   'message_partner_ids': [],
#   'message_ids': [],
#   'has_message': False,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'name': 'GretelGA',
#   'sequence': 1,
#   'description': False,
#   'description_purchase': False,
#   'description_sale': False,
#   'detailed_type': 'product',
#   'type': 'product',
#   'categ_id': [1, 'All'],
#   'currency_id': [32, 'MXN'],
#   'cost_currency_id': [32, 'MXN'],
#   'list_price': 0.0,
#   'standard_price': 1.0,
#   'volume': 0.0,
#   'volume_uom_name': 'm³',
#   'weight': 0.0,
#   'weight_uom_name': 'kg',
#   'sale_ok': True,
#   'purchase_ok': True,
#   'uom_id': [1, 'Unidades'],
#   'uom_name': 'Unidades',
#   'uom_po_id': [1, 'Unidades'],
#   'company_id': False,
#   'packaging_ids': [],
#   'seller_ids': [],
#   'variant_seller_ids': [],
#   'active': True,
#   'color': 0,
#   'is_product_variant': False,
#   'attribute_line_ids': [],
#   'valid_product_template_attribute_line_ids': [],
#   'product_variant_ids': [26517],
#   'product_variant_id': [26517, '[799] GretelGA'],
#   'product_variant_count': 1,
#   'barcode': '799',
#   'default_code': '799',
#   'pricelist_item_count': 0,
#   'product_document_ids': [],
#   'product_document_count': 0,
#   'can_image_1024_be_zoomed': False,
#   'has_configurable_attributes': False,
#   'product_tooltip': 'Los productos almacenables son artículos físicos para los que se gestiona el nivel de inventario.',
#   'priority': '0',
#   'product_tag_ids': [],
#   'product_properties': [],
#   'display_name': '[799] GretelGA',
#   'create_uid': [230, 'Pavel Hernandez Reza'],
#   'create_date': '2024-01-04 15:21:30',
#   'write_uid': [2, 'Lic. Costich'],
#   'write_date': '2024-04-16 00:40:58',
#   'taxes_id': [14, 60],
#   'tax_string': ' ',
#   'supplier_taxes_id': [23, 69],
#   'property_account_income_id': False,
#   'property_account_expense_id': False,
#   'account_tag_ids': [],
#   'fiscal_country_codes': 'MX',
#   'responsible_id': [230, 'Pavel Hernandez Reza'],
#   'property_stock_production': [15, 'Virtual Locations/Production'],
#   'property_stock_inventory': [14, 'Virtual Locations/Inventory adjustment'],
#   'sale_delay': 0,
#   'tracking': 'none',
#   'description_picking': False,
#   'description_pickingout': False,
#   'description_pickingin': False,
#   'qty_available': 0.0,
#   'virtual_available': 0.0,
#   'incoming_qty': 0.0,
#   'outgoing_qty': 0.0,
#   'location_id': False,
#   'warehouse_id': False,
#   'has_available_route_ids': True,
#   'route_ids': [5],
#   'nbr_moves_in': 0,
#   'nbr_moves_out': 0,
#   'nbr_reordering_rules': 0,
#   'reordering_min_qty': 0.0,
#   'reordering_max_qty': 0.0,
#   'route_from_categ_ids': [],
#   'show_on_hand_qty_status_button': True,
#   'show_forecasted_qty_status_button': True,
#   'unspsc_code_id': [26125, '49101609 Ornaments or decorations'],
#   'purchased_product_qty': 0.0,
#   'purchase_method': 'receive',
#   'purchase_line_warn': 'no-message',
#   'purchase_line_warn_msg': False,
#   'cost_method': 'standard',
#   'valuation': 'manual_periodic',
#   'available_in_pos': True,
#   'to_weight': False,
#   'pos_categ_ids': [],
#   'combo_ids': [],
#   'property_account_creditor_price_difference': False,
#   'service_type': 'manual',
#   'sale_line_warn': 'no-message',
#   'sale_line_warn_msg': False,
#   'expense_policy': 'no',
#   'visible_expense_policy': False,
#   'sales_count': 0.0,
#   'invoice_policy': 'order',
#   'optional_product_ids': [],
#   'service_to_purchase': False,
#   'planning_enabled': False,
#   'planning_role_id': False,
#   'service_tracking': 'no',
#   'project_id': False,
#   'project_template_id': False,
#   'service_policy': 'ordered_prepaid',
#   'documents_allowed_company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'project_template_use_documents': False,
#   'template_folder_id': False}]
