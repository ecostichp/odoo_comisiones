# %%
import xmlrpc.client
import os
import pandas as pd

api_url = os.environ.get('ODOO_URL_API')
api_db = os.environ.get('ODOO_DB_API')
api_username = os.environ.get('ODOO_USERNAME_API')
api_clave = os.environ.get('ODOO_CLAVE_API')

common = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/common')
uid = common.authenticate(api_db, api_username, api_clave, {})
models = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/object')

# %%
ids = models.execute_kw(api_db, uid, api_clave, 'pos.payment', 'search', [["&", ("payment_date", ">=", "2024-02-25"), ("payment_date", "<=", "2024-03-31")]])
wep = models.execute_kw(api_db, uid, api_clave, 'pos.payment', 'read', [ids])
wep
# Out:
# [{'id': 11406,
#   'name': False,
#   'pos_order_id': [7990, 'PdV SJC/4605'],
#   'amount': 1537.84,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 22:08:14',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [14443, 'ROAN MOBILIARIO SOBRE DISEÑO'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36198,
#    'PV1A2/2024/03/0348 (Pago de factura para PdV SJC/4605 [...])'],
#   'display_name': '$\xa01,537.84',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 22:08:10',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 22:08:10',
#   'online_account_payment_id': False},
#  {'id': 11405,
#   'name': False,
#   'pos_order_id': [7989, 'PdV CSL/3207'],
#   'amount': 3.99,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 22:04:44',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [414, 'Emilio Costich Perez'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36195,
#    'PV1A1/2024/03/0209 (Pago de factura para PdV CSL/3207 [...])'],
#   'display_name': '$\xa03.99',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 22:04:44',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 22:04:44',
#   'online_account_payment_id': False},
#  {'id': 11404,
#   'name': False,
#   'pos_order_id': [7988, 'PdV SJC/4604'],
#   'amount': 471.54,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 22:04:38',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36192,
#    'PV1A2/2024/03/0347 (Pago de factura para PdV SJC/4604 [...])'],
#   'display_name': '$\xa0471.54',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 22:04:34',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 22:04:34',
#   'online_account_payment_id': False},
#  {'id': 11403,
#   'name': False,
#   'pos_order_id': [7987, 'PdV SJC/4603'],
#   'amount': 112.22,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-03-04 21:59:47',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36188,
#    'PV1A2/2024/03/0346 (Pago de factura para PdV SJC/4603 [...])'],
#   'display_name': '$\xa0112.22',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:59:43',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:59:43',
#   'online_account_payment_id': False},
#  {'id': 11402,
#   'name': False,
#   'pos_order_id': [7986, 'PdV CSL/3206'],
#   'amount': 1777.77,
#   'payment_method_id': [29, 'Tarjeta Débito A1'],
#   'payment_date': '2024-03-04 21:47:04',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15437, 'MUEBLES Y ARTESANIAS EL ATICO'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36185,
#    'PV1A1/2024/03/0208 (Pago de factura para PdV CSL/3206 [...])'],
#   'display_name': '$\xa01,777.77',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 21:47:04',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 21:47:04',
#   'online_account_payment_id': False},
#  {'id': 11401,
#   'name': False,
#   'pos_order_id': [7985, 'PdV SJC/4602'],
#   'amount': 360.89,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:43:35',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16627, 'Erika Victoria Bory Arzate'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36182,
#    'PV1A2/2024/03/0345 (Pago de factura para PdV SJC/4602 [...])'],
#   'display_name': '$\xa0360.89',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:43:32',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:43:32',
#   'online_account_payment_id': False},
#  {'id': 11400,
#   'name': False,
#   'pos_order_id': [7984, 'PdV SJC/4601'],
#   'amount': 109.11,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-03-04 21:38:16',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36179,
#    'PV1A2/2024/03/0344 (Pago de factura para PdV SJC/4601 [...])'],
#   'display_name': '$\xa0109.11',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:38:13',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:38:13',
#   'online_account_payment_id': False},
#  {'id': 11399,
#   'name': False,
#   'pos_order_id': [7983, 'PdV CSL/3205'],
#   'amount': 991.29,
#   'payment_method_id': [29, 'Tarjeta Débito A1'],
#   'payment_date': '2024-03-04 21:36:16',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36176,
#    'PV1A1/2024/03/0207 (Pago de factura para PdV CSL/3205 [...])'],
#   'display_name': '$\xa0991.29',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 21:36:16',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 21:36:16',
#   'online_account_payment_id': False},
#  {'id': 11398,
#   'name': False,
#   'pos_order_id': [7982, 'PdV SJC/4600'],
#   'amount': 57.43,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:32:08',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36173,
#    'PV1A2/2024/03/0343 (Pago de factura para PdV SJC/4600 [...])'],
#   'display_name': '$\xa057.43',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:32:05',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:32:05',
#   'online_account_payment_id': False},
#  {'id': 11397,
#   'name': False,
#   'pos_order_id': [7981, 'PdV SJC/4599'],
#   'amount': 196.35,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:30:50',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36170,
#    'PV1A2/2024/03/0342 (Pago de factura para PdV SJC/4599 [...])'],
#   'display_name': '$\xa0196.35',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:30:47',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:30:47',
#   'online_account_payment_id': False},
#  {'id': 11396,
#   'name': 'devolver',
#   'pos_order_id': [7980, 'PdV SJC/4598'],
#   'amount': -4.04,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:11:05',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36165,
#    'PV1A2/2024/03/0340 (Pago de factura para PdV SJC/4598 [...])'],
#   'display_name': 'devolver $\xa0-4.04',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:11:05',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:11:05',
#   'online_account_payment_id': False},
#  {'id': 11395,
#   'name': False,
#   'pos_order_id': [7980, 'PdV SJC/4598'],
#   'amount': 30.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:11:09',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36166,
#    'PV1A2/2024/03/0341 (Pago de factura para PdV SJC/4598 [...])'],
#   'display_name': '$\xa030.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:11:05',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:11:05',
#   'online_account_payment_id': False},
#  {'id': 11394,
#   'name': 'devolver',
#   'pos_order_id': [7979, 'PdV SJC/4597'],
#   'amount': -3.74,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:07:53',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36161,
#    'PV1A2/2024/03/0338 (Pago de factura para PdV SJC/4597 [...])'],
#   'display_name': 'devolver $\xa0-3.74',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:07:53',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:07:53',
#   'online_account_payment_id': False},
#  {'id': 11393,
#   'name': False,
#   'pos_order_id': [7979, 'PdV SJC/4597'],
#   'amount': 320.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:07:56',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36162,
#    'PV1A2/2024/03/0339 (Pago de factura para PdV SJC/4597 [...])'],
#   'display_name': '$\xa0320.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:07:53',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:07:53',
#   'online_account_payment_id': False},
#  {'id': 11392,
#   'name': 'devolver',
#   'pos_order_id': [7978, 'PdV SJC/4596'],
#   'amount': -161.95,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:06:24',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13050, 'ESTUDIO PACIFICO ARQUITECTURA MEXICANA'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36157,
#    'PV1A2/2024/03/0336 (Pago de factura para PdV SJC/4596 [...])'],
#   'display_name': 'devolver $\xa0-161.95',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:06:24',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:06:24',
#   'online_account_payment_id': False},
#  {'id': 11391,
#   'name': False,
#   'pos_order_id': [7978, 'PdV SJC/4596'],
#   'amount': 500.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 21:06:28',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13050, 'ESTUDIO PACIFICO ARQUITECTURA MEXICANA'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36158,
#    'PV1A2/2024/03/0337 (Pago de factura para PdV SJC/4596 [...])'],
#   'display_name': '$\xa0500.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 21:06:24',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 21:06:24',
#   'online_account_payment_id': False},
#  {'id': 11390,
#   'name': False,
#   'pos_order_id': [7977, 'PdV CSL/3204'],
#   'amount': 751.68,
#   'payment_method_id': [5, 'Transferencia Banco Sant92000702524'],
#   'payment_date': '2024-03-04 21:03:11',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15891, 'VICTORINO LOPEZ GAMEZ'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36154,
#    'PV1A1/2024/03/0206 (Pago de factura para PdV CSL/3204 [...])'],
#   'display_name': '$\xa0751.68',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 21:03:11',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 21:03:13',
#   'online_account_payment_id': False},
#  {'id': 11389,
#   'name': 'devolver',
#   'pos_order_id': [7976, 'PdV SJC/4595'],
#   'amount': -27.3,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:54:34',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36150,
#    'PV1A2/2024/03/0334 (Pago de factura para PdV SJC/4595 [...])'],
#   'display_name': 'devolver $\xa0-27.30',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:54:34',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:54:34',
#   'online_account_payment_id': False},
#  {'id': 11388,
#   'name': False,
#   'pos_order_id': [7976, 'PdV SJC/4595'],
#   'amount': 100.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:54:38',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36151,
#    'PV1A2/2024/03/0335 (Pago de factura para PdV SJC/4595 [...])'],
#   'display_name': '$\xa0100.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:54:34',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:54:34',
#   'online_account_payment_id': False},
#  {'id': 11387,
#   'name': 'devolver',
#   'pos_order_id': [7975, 'PdV SJC/4594'],
#   'amount': -0.3,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:46:01',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36146,
#    'PV1A2/2024/03/0332 (Pago de factura para PdV SJC/4594 [...])'],
#   'display_name': 'devolver $\xa0-0.30',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:46:01',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:46:01',
#   'online_account_payment_id': False},
#  {'id': 11386,
#   'name': False,
#   'pos_order_id': [7975, 'PdV SJC/4594'],
#   'amount': 150.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:46:05',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36147,
#    'PV1A2/2024/03/0333 (Pago de factura para PdV SJC/4594 [...])'],
#   'display_name': '$\xa0150.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:46:01',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:46:01',
#   'online_account_payment_id': False},
#  {'id': 11385,
#   'name': 'devolver',
#   'pos_order_id': [7974, 'PdV SJC/4593'],
#   'amount': -0.11,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:43:12',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16627, 'Erika Victoria Bory Arzate'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36142,
#    'PV1A2/2024/03/0330 (Pago de factura para PdV SJC/4593 [...])'],
#   'display_name': 'devolver $\xa0-0.11',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:43:12',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:43:12',
#   'online_account_payment_id': False},
#  {'id': 11384,
#   'name': False,
#   'pos_order_id': [7974, 'PdV SJC/4593'],
#   'amount': 361.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:43:15',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16627, 'Erika Victoria Bory Arzate'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36143,
#    'PV1A2/2024/03/0331 (Pago de factura para PdV SJC/4593 [...])'],
#   'display_name': '$\xa0361.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:43:12',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:43:12',
#   'online_account_payment_id': False},
#  {'id': 11383,
#   'name': False,
#   'pos_order_id': [7973, 'PdV SJC/4592'],
#   'amount': 358.15,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-03-04 20:41:23',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13305, 'LUIS MANUEL GUEREÑA GARCIA'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36139,
#    'PV1A2/2024/03/0329 (Pago de factura para PdV SJC/4592 [...])'],
#   'display_name': '$\xa0358.15',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:41:19',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:41:19',
#   'online_account_payment_id': False},
#  {'id': 11382,
#   'name': False,
#   'pos_order_id': [7972, 'PdV SJC/4591'],
#   'amount': 131.08,
#   'payment_method_id': [31, 'Tarjeta Crédito A2'],
#   'payment_date': '2024-03-04 20:39:20',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15338, 'MANTENIMIENTO CASAS DE PLAYA'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36136,
#    'PV1A2/2024/03/0328 (Pago de factura para PdV SJC/4591 [...])'],
#   'display_name': '$\xa0131.08',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:39:17',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:39:17',
#   'online_account_payment_id': False},
#  {'id': 11381,
#   'name': False,
#   'pos_order_id': [7971, 'PdV SJC/4590'],
#   'amount': 220.98,
#   'payment_method_id': [31, 'Tarjeta Crédito A2'],
#   'payment_date': '2024-03-04 20:38:06',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15338, 'MANTENIMIENTO CASAS DE PLAYA'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36133,
#    'PV1A2/2024/03/0327 (Pago de factura para PdV SJC/4590 [...])'],
#   'display_name': '$\xa0220.98',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:38:03',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:38:03',
#   'online_account_payment_id': False},
#  {'id': 11380,
#   'name': False,
#   'pos_order_id': [7970, 'PdV SJC/4589'],
#   'amount': 195.96,
#   'payment_method_id': [31, 'Tarjeta Crédito A2'],
#   'payment_date': '2024-03-04 20:36:41',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15338, 'MANTENIMIENTO CASAS DE PLAYA'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36130,
#    'PV1A2/2024/03/0326 (Pago de factura para PdV SJC/4589 [...])'],
#   'display_name': '$\xa0195.96',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:36:37',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:36:37',
#   'online_account_payment_id': False},
#  {'id': 11379,
#   'name': False,
#   'pos_order_id': [7969, 'PdV CSL/3203'],
#   'amount': 11.07,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:35:08',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [414, 'Emilio Costich Perez'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36127,
#    'PV1A1/2024/03/0205 (Pago de factura para PdV CSL/3203 [...])'],
#   'display_name': '$\xa011.07',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:35:08',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:35:08',
#   'online_account_payment_id': False},
#  {'id': 11378,
#   'name': False,
#   'pos_order_id': [7968, 'PdV CSL/3202'],
#   'amount': 377.73,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:29:03',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15969, 'CRUZ DOMINGO CHAVEZ CAMACHO'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36124,
#    'PV1A1/2024/03/0204 (Pago de factura para PdV CSL/3202 [...])'],
#   'display_name': '$\xa0377.73',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:29:03',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:29:03',
#   'online_account_payment_id': False},
#  {'id': 11377,
#   'name': False,
#   'pos_order_id': [7967, 'PdV CSL/3201'],
#   'amount': 1868.63,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:27:36',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15969, 'CRUZ DOMINGO CHAVEZ CAMACHO'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36121,
#    'PV1A1/2024/03/0203 (Pago de factura para PdV CSL/3201 [...])'],
#   'display_name': '$\xa01,868.63',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:27:36',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:27:36',
#   'online_account_payment_id': False},
#  {'id': 11376,
#   'name': 'devolver',
#   'pos_order_id': [7966, 'PdV SJC/4588'],
#   'amount': -171.14,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:24:38',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36117,
#    'PV1A2/2024/03/0324 (Pago de factura para PdV SJC/4588 [...])'],
#   'display_name': 'devolver $\xa0-171.14',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:24:37',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:24:37',
#   'online_account_payment_id': False},
#  {'id': 11375,
#   'name': False,
#   'pos_order_id': [7966, 'PdV SJC/4588'],
#   'amount': 500.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:24:41',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36118,
#    'PV1A2/2024/03/0325 (Pago de factura para PdV SJC/4588 [...])'],
#   'display_name': '$\xa0500.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:24:37',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:24:37',
#   'online_account_payment_id': False},
#  {'id': 11374,
#   'name': 'devolver',
#   'pos_order_id': [7965, 'PdV CSL/3200'],
#   'amount': -20.9,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:24:29',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [414, 'Emilio Costich Perez'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36113,
#    'PV1A1/2024/03/0201 (Pago de factura para PdV CSL/3200 [...])'],
#   'display_name': 'devolver $\xa0-20.90',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:24:29',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:24:29',
#   'online_account_payment_id': False},
#  {'id': 11373,
#   'name': False,
#   'pos_order_id': [7965, 'PdV CSL/3200'],
#   'amount': 200.0,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:24:28',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [414, 'Emilio Costich Perez'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36114,
#    'PV1A1/2024/03/0202 (Pago de factura para PdV CSL/3200 [...])'],
#   'display_name': '$\xa0200.00',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:24:29',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:24:29',
#   'online_account_payment_id': False},
#  {'id': 11372,
#   'name': False,
#   'pos_order_id': [7964, 'PdV SJC/4587'],
#   'amount': 805.28,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-03-04 20:23:18',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16507, 'Andres Rodriguez Flores'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36110,
#    'PV1A2/2024/03/0323 (Pago de factura para PdV SJC/4587 [...])'],
#   'display_name': '$\xa0805.28',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:23:14',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:23:14',
#   'online_account_payment_id': False},
#  {'id': 11371,
#   'name': 'devolver',
#   'pos_order_id': [7963, 'PdV CSL/3199'],
#   'amount': -403.02,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:22:08',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [414, 'Emilio Costich Perez'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36106,
#    'PV1A1/2024/03/0199 (Pago de factura para PdV CSL/3199 [...])'],
#   'display_name': 'devolver $\xa0-403.02',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:22:08',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:22:08',
#   'online_account_payment_id': False},
#  {'id': 11370,
#   'name': False,
#   'pos_order_id': [7963, 'PdV CSL/3199'],
#   'amount': 1020.0,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:22:08',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [414, 'Emilio Costich Perez'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36107,
#    'PV1A1/2024/03/0200 (Pago de factura para PdV CSL/3199 [...])'],
#   'display_name': '$\xa01,020.00',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:22:08',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:22:08',
#   'online_account_payment_id': False},
#  {'id': 11369,
#   'name': False,
#   'pos_order_id': [7962, 'PdV SJC/4586'],
#   'amount': 565.19,
#   'payment_method_id': [6, 'Crédito del cliente'],
#   'payment_date': '2024-03-04 20:18:38',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13803, 'STANLEY PARK'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': False,
#   'display_name': '$\xa0565.19',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:18:34',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:18:34',
#   'online_account_payment_id': False},
#  {'id': 11368,
#   'name': False,
#   'pos_order_id': [7961, 'PdV CSL/3198'],
#   'amount': 1305.7,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:17:40',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15373, 'AURORA YANET CRUZ AMAYA'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36102,
#    'PV1A1/2024/03/0198 (Pago de factura para PdV CSL/3198 [...])'],
#   'display_name': '$\xa01,305.70',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:17:40',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:17:40',
#   'online_account_payment_id': False},
#  {'id': 11367,
#   'name': False,
#   'pos_order_id': [7960, 'PdV SJC/4585'],
#   'amount': 1814.8,
#   'payment_method_id': [6, 'Crédito del cliente'],
#   'payment_date': '2024-03-04 20:17:20',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13803, 'STANLEY PARK'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': False,
#   'display_name': '$\xa01,814.80',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:17:16',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:17:16',
#   'online_account_payment_id': False},
#  {'id': 11366,
#   'name': False,
#   'pos_order_id': [7959, 'PdV CSL/3197'],
#   'amount': 4173.66,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:17:04',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15373, 'AURORA YANET CRUZ AMAYA'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36098,
#    'PV1A1/2024/03/0197 (Pago de factura para PdV CSL/3197 [...])'],
#   'display_name': '$\xa04,173.66',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:17:04',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:17:04',
#   'online_account_payment_id': False},
#  {'id': 11365,
#   'name': False,
#   'pos_order_id': [7958, 'PdV SJC/4584'],
#   'amount': 2986.14,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-03-04 20:12:15',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36093,
#    'PV1A2/2024/03/0321 (Pago de factura para PdV SJC/4584 [...])'],
#   'display_name': '$\xa02,986.14',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:12:12',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:12:12',
#   'online_account_payment_id': False},
#  {'id': 11364,
#   'name': False,
#   'pos_order_id': [7958, 'PdV SJC/4584'],
#   'amount': 5000.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:12:15',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36094,
#    'PV1A2/2024/03/0322 (Pago de factura para PdV SJC/4584 [...])'],
#   'display_name': '$\xa05,000.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:12:12',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:12:12',
#   'online_account_payment_id': False},
#  {'id': 11363,
#   'name': False,
#   'pos_order_id': [7957, 'PdV CSL/3196'],
#   'amount': 380.35,
#   'payment_method_id': [29, 'Tarjeta Débito A1'],
#   'payment_date': '2024-03-04 20:10:51',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15943, 'ANA GABRIELA RIVERA GONZALEZ'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36090,
#    'PV1A1/2024/03/0196 (Pago de factura para PdV CSL/3196 [...])'],
#   'display_name': '$\xa0380.35',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:10:51',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:10:51',
#   'online_account_payment_id': False},
#  {'id': 11362,
#   'name': False,
#   'pos_order_id': [7956, 'PdV CSL/3195'],
#   'amount': 1988.55,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 20:03:11',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15969, 'CRUZ DOMINGO CHAVEZ CAMACHO'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36087,
#    'PV1A1/2024/03/0195 (Pago de factura para PdV CSL/3195 [...])'],
#   'display_name': '$\xa01,988.55',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 20:03:11',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 20:03:11',
#   'online_account_payment_id': False},
#  {'id': 11361,
#   'name': 'devolver',
#   'pos_order_id': [7955, 'PdV SJC/4583'],
#   'amount': -5.84,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:00:53',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36083,
#    'PV1A2/2024/03/0319 (Pago de factura para PdV SJC/4583 [...])'],
#   'display_name': 'devolver $\xa0-5.84',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:00:53',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:00:53',
#   'online_account_payment_id': False},
#  {'id': 11360,
#   'name': False,
#   'pos_order_id': [7955, 'PdV SJC/4583'],
#   'amount': 200.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 20:00:56',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36084,
#    'PV1A2/2024/03/0320 (Pago de factura para PdV SJC/4583 [...])'],
#   'display_name': '$\xa0200.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 20:00:53',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 20:00:53',
#   'online_account_payment_id': False},
#  {'id': 11359,
#   'name': 'devolver',
#   'pos_order_id': [7954, 'PdV SJC/4582'],
#   'amount': -0.15,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 19:53:14',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16209, 'Angelica Torres Estrada'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36079,
#    'PV1A2/2024/03/0317 (Pago de factura para PdV SJC/4582 [...])'],
#   'display_name': 'devolver $\xa0-0.15',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 19:53:14',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 19:53:15',
#   'online_account_payment_id': False},
#  {'id': 11358,
#   'name': False,
#   'pos_order_id': [7954, 'PdV SJC/4582'],
#   'amount': 45.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 19:53:17',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16209, 'Angelica Torres Estrada'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36080,
#    'PV1A2/2024/03/0318 (Pago de factura para PdV SJC/4582 [...])'],
#   'display_name': '$\xa045.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 19:53:14',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 19:53:15',
#   'online_account_payment_id': False},
#  {'id': 11357,
#   'name': False,
#   'pos_order_id': [7953, 'PdV SJC/4581'],
#   'amount': 408.41,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-03-04 19:34:49',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36076,
#    'PV1A2/2024/03/0316 (Pago de factura para PdV SJC/4581 [...])'],
#   'display_name': '$\xa0408.41',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 19:34:45',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 19:34:45',
#   'online_account_payment_id': False},
#  {'id': 11356,
#   'name': 'devolver',
#   'pos_order_id': [7952, 'PdV SJC/4580'],
#   'amount': -53.5,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 19:32:34',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36072,
#    'PV1A2/2024/03/0314 (Pago de factura para PdV SJC/4580 [...])'],
#   'display_name': 'devolver $\xa0-53.50',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 19:32:34',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 19:32:34',
#   'online_account_payment_id': False},
#  {'id': 11355,
#   'name': False,
#   'pos_order_id': [7952, 'PdV SJC/4580'],
#   'amount': 400.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 19:32:37',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36073,
#    'PV1A2/2024/03/0315 (Pago de factura para PdV SJC/4580 [...])'],
#   'display_name': '$\xa0400.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 19:32:34',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 19:32:34',
#   'online_account_payment_id': False},
#  {'id': 11354,
#   'name': False,
#   'pos_order_id': [7951, 'PdV SJC/4579'],
#   'amount': 411.23,
#   'payment_method_id': [31, 'Tarjeta Crédito A2'],
#   'payment_date': '2024-03-04 19:30:51',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13432, 'ORLANDO CASTAÑEDA ALANIZ'],
#   'session_id': [121, 'POS/00121'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36069,
#    'PV1A2/2024/03/0313 (Pago de factura para PdV SJC/4579 [...])'],
#   'display_name': '$\xa0411.23',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-03-04 19:30:48',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-03-04 19:30:48',
#   'online_account_payment_id': False},
#  {'id': 11353,
#   'name': 'devolver',
#   'pos_order_id': [7950, 'PdV CSL/3194'],
#   'amount': -242.16,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 19:28:46',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15796, 'JUAN CARLOS NEGRETE GARCIA'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [36065,
#    'PV1A1/2024/03/0193 (Pago de factura para PdV CSL/3194 [...])'],
#   'display_name': 'devolver $\xa0-242.16',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 19:28:46',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 19:28:46',
#   'online_account_payment_id': False},
#  {'id': 11352,
#   'name': False,
#   'pos_order_id': [7950, 'PdV CSL/3194'],
#   'amount': 3500.0,
#   'payment_method_id': [28, 'Efectivo A1'],
#   'payment_date': '2024-03-04 19:28:46',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15796, 'JUAN CARLOS NEGRETE GARCIA'],
#   'session_id': [120, 'POS/00120'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [36066,
#    'PV1A1/2024/03/0194 (Pago de factura para PdV CSL/3194 [...])'],
#   'display_name': '$\xa03,500.00',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-04 19:28:46',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-04 19:28:46',
#   'online_account_payment_id': False},
#  {'id': 11351,
#   'name': 'devolver',
#   'pos_order_id': [7949, 'PdV SJC/4578'],
#   'amount': -57.85,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-03-04 19:28:46',
#   'currency_id': [32, 'MXN'],
# ...
#   'display_name': '$\xa0520.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:32:57',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:32:57',
#   'online_account_payment_id': False},
#  {'id': 10424,
#   'name': False,
#   'pos_order_id': [7332, 'PdV SJC/4228'],
#   'amount': 180.55,
#   'payment_method_id': [31, 'Tarjeta Crédito A2'],
#   'payment_date': '2024-02-28 17:32:06',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32592,
#    'PV1A2/2024/02/2873 (Pago de factura para PdV SJC/4228 [...])'],
#   'display_name': '$\xa0180.55',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:32:05',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:32:05',
#   'online_account_payment_id': False},
#  {'id': 10423,
#   'name': False,
#   'pos_order_id': [7331, 'PdV SJC/4227'],
#   'amount': 1767.4,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-02-28 17:29:40',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13207, 'DANIEL REYES SANTIAGO'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32589,
#    'PV1A2/2024/02/2872 (Pago de factura para PdV SJC/4227 [...])'],
#   'display_name': '$\xa01,767.40',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:29:40',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:29:40',
#   'online_account_payment_id': False},
#  {'id': 10422,
#   'name': False,
#   'pos_order_id': [7330, 'PdV SJC/4226'],
#   'amount': 2850.43,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-02-28 17:26:42',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13064, 'DAVID ISRRAEL GUARDADO MENDEZ'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32586,
#    'PV1A2/2024/02/2871 (Pago de factura para PdV SJC/4226 [...])'],
#   'display_name': '$\xa02,850.43',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:26:41',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:26:41',
#   'online_account_payment_id': False},
#  {'id': 10421,
#   'name': 'devolver',
#   'pos_order_id': [7329, 'PdV SJC/4225'],
#   'amount': -61.72,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 17:22:54',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [32582,
#    'PV1A2/2024/02/2869 (Pago de factura para PdV SJC/4225 [...])'],
#   'display_name': 'devolver $\xa0-61.72',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:22:54',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:22:54',
#   'online_account_payment_id': False},
#  {'id': 10420,
#   'name': False,
#   'pos_order_id': [7329, 'PdV SJC/4225'],
#   'amount': 100.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 17:22:55',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32583,
#    'PV1A2/2024/02/2870 (Pago de factura para PdV SJC/4225 [...])'],
#   'display_name': '$\xa0100.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:22:54',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:22:54',
#   'online_account_payment_id': False},
#  {'id': 10419,
#   'name': False,
#   'pos_order_id': [7328, 'PdV SJC/4224'],
#   'amount': 220.53,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 17:04:30',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32578,
#    'PV1A2/2024/02/2868 (Pago de factura para PdV SJC/4224 [...])'],
#   'display_name': '$\xa0220.53',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:04:29',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:04:29',
#   'online_account_payment_id': False},
#  {'id': 10418,
#   'name': 'devolver',
#   'pos_order_id': [7327, 'PdV SJC/4223'],
#   'amount': -9.13,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 17:02:44',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [32574,
#    'PV1A2/2024/02/2866 (Pago de factura para PdV SJC/4223 [...])'],
#   'display_name': 'devolver $\xa0-9.13',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:02:44',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:02:44',
#   'online_account_payment_id': False},
#  {'id': 10417,
#   'name': False,
#   'pos_order_id': [7327, 'PdV SJC/4223'],
#   'amount': 50.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 17:02:45',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32575,
#    'PV1A2/2024/02/2867 (Pago de factura para PdV SJC/4223 [...])'],
#   'display_name': '$\xa050.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:02:44',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:02:44',
#   'online_account_payment_id': False},
#  {'id': 10416,
#   'name': 'devolver',
#   'pos_order_id': [7326, 'PdV SJC/4222'],
#   'amount': -7.14,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 17:00:40',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [14528, 'PACIFIC FENESTRATION SOLUTIONS'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [32570,
#    'PV1A2/2024/02/2864 (Pago de factura para PdV SJC/4222 [...])'],
#   'display_name': 'devolver $\xa0-7.14',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:00:40',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:00:40',
#   'online_account_payment_id': False},
#  {'id': 10415,
#   'name': False,
#   'pos_order_id': [7326, 'PdV SJC/4222'],
#   'amount': 210.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 17:00:41',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [14528, 'PACIFIC FENESTRATION SOLUTIONS'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32571,
#    'PV1A2/2024/02/2865 (Pago de factura para PdV SJC/4222 [...])'],
#   'display_name': '$\xa0210.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 17:00:40',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 17:00:40',
#   'online_account_payment_id': False},
#  {'id': 10414,
#   'name': False,
#   'pos_order_id': [7325, 'PdV CSL/2934'],
#   'amount': 98.03,
#   'payment_method_id': [29, 'Tarjeta Débito A1'],
#   'payment_date': '2024-02-28 16:56:58',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [111, 'POS/00111'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32567,
#    'PV1A1/2024/02/2011 (Pago de factura para PdV CSL/2934 [...])'],
#   'display_name': '$\xa098.03',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-02-28 16:56:57',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-02-28 16:56:57',
#   'online_account_payment_id': False},
#  {'id': 10413,
#   'name': False,
#   'pos_order_id': [7324, 'PdV SJC/4221'],
#   'amount': 51.55,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 16:54:11',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [15791, 'JOSE MARIA NORIEGA SANCHEZ'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32564,
#    'PV1A2/2024/02/2863 (Pago de factura para PdV SJC/4221 [...])'],
#   'display_name': '$\xa051.55',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 16:54:10',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 16:54:10',
#   'online_account_payment_id': False},
#  {'id': 10412,
#   'name': False,
#   'pos_order_id': [7323, 'PdV SJC/4220'],
#   'amount': 384.54,
#   'payment_method_id': [5, 'Transferencia Banco Sant92000702524'],
#   'payment_date': '2024-02-28 16:51:55',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13623, 'FRONDOSO GROUNDWORKS'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32560,
#    'PV1A2/2024/02/2862 (Pago de factura para PdV SJC/4220 [...])'],
#   'display_name': '$\xa0384.54',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 16:51:54',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 16:51:54',
#   'online_account_payment_id': False},
#  {'id': 10411,
#   'name': 'devolver',
#   'pos_order_id': [7322, 'PdV SJC/4219'],
#   'amount': -1.7,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 16:50:52',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': False,
#   'cardholder_name': False,
#   'transaction_id': False,
#   'payment_status': False,
#   'ticket': False,
#   'is_change': True,
#   'account_move_id': [32556,
#    'PV1A2/2024/02/2860 (Pago de factura para PdV SJC/4219 [...])'],
#   'display_name': 'devolver $\xa0-1.70',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 16:50:52',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 16:50:52',
#   'online_account_payment_id': False},
#  {'id': 10410,
#   'name': False,
#   'pos_order_id': [7322, 'PdV SJC/4219'],
#   'amount': 40.0,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 16:50:53',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32557,
#    'PV1A2/2024/02/2861 (Pago de factura para PdV SJC/4219 [...])'],
#   'display_name': '$\xa040.00',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 16:50:52',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 16:50:52',
#   'online_account_payment_id': False},
#  {'id': 10409,
#   'name': False,
#   'pos_order_id': [7321, 'PdV SJC/4218'],
#   'amount': 69.28,
#   'payment_method_id': [34, 'Efectivo A2'],
#   'payment_date': '2024-02-28 16:50:13',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [16253, 'Mostrador'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32553,
#    'PV1A2/2024/02/2859 (Pago de factura para PdV SJC/4218 [...])'],
#   'display_name': '$\xa069.28',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 16:50:12',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 16:50:12',
#   'online_account_payment_id': False},
#  {'id': 10408,
#   'name': False,
#   'pos_order_id': [7320, 'PdV SJC/4217'],
#   'amount': 224.48,
#   'payment_method_id': [30, 'Tarjeta Débito A2'],
#   'payment_date': '2024-02-28 16:48:09',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [14383, 'SOCORRO SILLAS BURGOS'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32550,
#    'PV1A2/2024/02/2858 (Pago de factura para PdV SJC/4217 [...])'],
#   'display_name': '$\xa0224.48',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 16:48:08',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 16:48:08',
#   'online_account_payment_id': False},
#  {'id': 10407,
#   'name': False,
#   'pos_order_id': [7319, 'PdV SJC/4216'],
#   'amount': 962.59,
#   'payment_method_id': [31, 'Tarjeta Crédito A2'],
#   'payment_date': '2024-02-28 16:44:31',
#   'currency_id': [32, 'MXN'],
#   'currency_rate': 1.0,
#   'partner_id': [13207, 'DANIEL REYES SANTIAGO'],
#   'session_id': [112, 'POS/00112'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'card_type': '',
#   'cardholder_name': '',
#   'transaction_id': '',
#   'payment_status': '',
#   'ticket': '',
#   'is_change': False,
#   'account_move_id': [32547,
#    'PV1A2/2024/02/2857 (Pago de factura para PdV SJC/4216 [...])'],
#   'display_name': '$\xa0962.59',
#   'create_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'create_date': '2024-02-28 16:44:30',
#   'write_uid': [238, 'Karely Guadalupe Green Ceseña'],
#   'write_date': '2024-02-28 16:44:30',
#   'online_account_payment_id': False},
#  ...]
