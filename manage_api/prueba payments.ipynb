# %%
import xmlrpc.client
import os
import pandas as pd

api_url = os.environ.get('ODOO_URL_API')
api_db = os.environ.get('ODOO_DB_API')
api_username = os.environ.get('ODOO_USERNAME_API')
api_clave = os.environ.get('ODOO_CLAVE_API')

common = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/common')
uid = common.authenticate(api_db, api_username, api_clave, {})
models = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/object')

# %%
ids = models.execute_kw(api_db, uid, api_clave, 'account.payment', 'search', [["&", ("date", ">=", "2024-02-25"), ("date", "<=", "2024-03-31")]])
wep = models.execute_kw(api_db, uid, api_clave, 'account.payment', 'read', [ids])
wep
# Out:
# [{'id': 514,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [100875],
#   'message_partner_ids': [223],
#   'message_ids': [192681],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [35675,
#    'PT2-CC/2024/00109 (Combine Tarjeta Crédito A2 pagos de PdV de [...])'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [51, 'Manual'],
#   'available_payment_method_line_ids': [51],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 29246.33,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': False,
#   'outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [50, '105.01.02 Clientes nacionales (PdV)'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [],
#   'reconciled_invoices_count': 0,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': True,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 29246.33,
#   'amount_company_currency_signed': 29246.33,
#   'display_name': 'PT2-CC/2024/00109',
#   'create_uid': [222, 'Yolanda Alejandra Rodriguez González'],
#   'create_date': '2024-03-02 23:02:37',
#   'write_uid': [222, 'Yolanda Alejandra Rodriguez González'],
#   'write_date': '2024-03-02 23:02:37',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': [31, 'Tarjeta Crédito A2'],
#   'force_outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'pos_session_id': [118, 'POS/00118'],
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PT2-CC/2024/',
#   'sequence_number': 109,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PT2-CC/2024/00109',
#   'ref': 'Combine Tarjeta Crédito A2 pagos de PdV de POS/00118',
#   'date': '2024-03-02',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [100, 'Tarjeta Deb/Cré A2'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [133027, 133028],
#   'payment_id': [514, 'PT2-CC/2024/00109'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PT2-CC/2024/00108',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-03-02","journal_id":"100","line_133027_account_id":"98","line_133027_credit":"0.00","line_133027_debit":"29246.33","line_133027_name":"Pago de cliente $\\u00a029,246.33 - 02/03/2024","line_133027_partner_id":"False","line_133028_account_id":"50","line_133028_credit":"29246.33","line_133028_debit":"0.00","line_133028_name":"Pago de cliente $\\u00a029,246.33 - 02/03/2024","line_133028_partner_id":"False","name":"PT2-CC/2024/00109"}',
#   'invoice_line_ids': [133027, 133028],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-02',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_globally',
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 29246.33,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 29246.33,
#   'amount_total_in_currency_signed': 29246.33,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'VEINTINUEVE MIL DOSCIENTOS CUARENTA Y SEIS PESOS 33/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Yolanda Alejandra Rodriguez González',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [514],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-03-02 16:02:38',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [6, 'A2 SJC'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 513,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [100873],
#   'message_partner_ids': [223],
#   'message_ids': [192679],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [35674,
#    'PT2-CC/2024/00108 (Combine Tarjeta Débito A2 pagos de PdV de [...])'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [51, 'Manual'],
#   'available_payment_method_line_ids': [51],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 15809.79,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': False,
#   'outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [50, '105.01.02 Clientes nacionales (PdV)'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [],
#   'reconciled_invoices_count': 0,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': True,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 15809.79,
#   'amount_company_currency_signed': 15809.79,
#   'display_name': 'PT2-CC/2024/00108',
#   'create_uid': [222, 'Yolanda Alejandra Rodriguez González'],
#   'create_date': '2024-03-02 23:02:37',
#   'write_uid': [222, 'Yolanda Alejandra Rodriguez González'],
#   'write_date': '2024-03-02 23:02:37',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': [30, 'Tarjeta Débito A2'],
#   'force_outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'pos_session_id': [118, 'POS/00118'],
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PT2-CC/2024/',
#   'sequence_number': 108,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PT2-CC/2024/00108',
#   'ref': 'Combine Tarjeta Débito A2 pagos de PdV de POS/00118',
#   'date': '2024-03-02',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [100, 'Tarjeta Deb/Cré A2'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [133024, 133025],
#   'payment_id': [513, 'PT2-CC/2024/00108'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PT2-CC/2024/00109',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-03-02","journal_id":"100","line_133024_account_id":"98","line_133024_credit":"0.00","line_133024_debit":"15809.79","line_133024_name":"Pago de cliente $\\u00a015,809.79 - 02/03/2024","line_133024_partner_id":"False","line_133025_account_id":"50","line_133025_credit":"15809.79","line_133025_debit":"0.00","line_133025_name":"Pago de cliente $\\u00a015,809.79 - 02/03/2024","line_133025_partner_id":"False","name":"PT2-CC/2024/00108"}',
#   'invoice_line_ids': [133024, 133025],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-02',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_globally',
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 15809.79,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 15809.79,
#   'amount_total_in_currency_signed': 15809.79,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'QUINCE MIL OCHOCIENTOS NUEVE PESOS 79/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Yolanda Alejandra Rodriguez González',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [513],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-03-02 16:02:38',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [6, 'A2 SJC'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 511,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [100862],
#   'message_partner_ids': [16357],
#   'message_ids': [192661],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [35670,
#    'PT1-CC/2024/00113 (Combine Tarjeta Débito A1 pagos de PdV de [...])'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [49, 'Manual'],
#   'available_payment_method_line_ids': [49],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 1342.18,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': False,
#   'outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [50, '105.01.02 Clientes nacionales (PdV)'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [],
#   'reconciled_invoices_count': 0,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': True,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 1342.18,
#   'amount_company_currency_signed': 1342.18,
#   'display_name': 'PT1-CC/2024/00113',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-02 22:43:13',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-02 22:43:13',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': [29, 'Tarjeta Débito A1'],
#   'force_outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'pos_session_id': [119, 'POS/00119'],
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PT1-CC/2024/',
#   'sequence_number': 113,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PT1-CC/2024/00113',
#   'ref': 'Combine Tarjeta Débito A1 pagos de PdV de POS/00119',
#   'date': '2024-03-02',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [99, 'Tarjeta Deb/Cré A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [133010, 133011],
#   'payment_id': [511, 'PT1-CC/2024/00113'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PT1-CC/2024/00112',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-03-02","journal_id":"99","line_133010_account_id":"98","line_133010_credit":"0.00","line_133010_debit":"1342.18","line_133010_name":"Pago de cliente $\\u00a01,342.18 - 02/03/2024","line_133010_partner_id":"False","line_133011_account_id":"50","line_133011_credit":"1342.18","line_133011_debit":"0.00","line_133011_name":"Pago de cliente $\\u00a01,342.18 - 02/03/2024","line_133011_partner_id":"False","name":"PT1-CC/2024/00113"}',
#   'invoice_line_ids': [133010, 133011],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-02',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_globally',
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 1342.18,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 1342.18,
#   'amount_total_in_currency_signed': 1342.18,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'MIL TRESCIENTOS CUARENTA Y DOS PESOS 18/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Rosa Brenda Avilez Ceseña',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [511],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-03-02 15:43:14',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [1, 'Sales'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 502,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [100419],
#   'message_partner_ids': [16357],
#   'message_ids': [191849],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [35484,
#    'PT1-CC/2024/00112 (Combine Tarjeta Crédito A1 pagos de PdV de [...])'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [49, 'Manual'],
#   'available_payment_method_line_ids': [49],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 3669.95,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': False,
#   'outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [50, '105.01.02 Clientes nacionales (PdV)'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [],
#   'reconciled_invoices_count': 0,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': True,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 3669.9500000000003,
#   'amount_company_currency_signed': 3669.95,
#   'display_name': 'PT1-CC/2024/00112',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-02 20:35:37',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-02 20:35:37',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': [32, 'Tarjeta Crédito A1'],
#   'force_outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'pos_session_id': [117, 'POS/00117'],
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PT1-CC/2024/',
#   'sequence_number': 112,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PT1-CC/2024/00112',
#   'ref': 'Combine Tarjeta Crédito A1 pagos de PdV de POS/00117',
#   'date': '2024-03-02',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [99, 'Tarjeta Deb/Cré A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [132403, 132404],
#   'payment_id': [502, 'PT1-CC/2024/00112'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PT1-CC/2024/00113',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-03-02","journal_id":"99","line_132403_account_id":"98","line_132403_credit":"0.00","line_132403_debit":"3669.95","line_132403_name":"Pago de cliente $\\u00a03,669.95 - 02/03/2024","line_132403_partner_id":"False","line_132404_account_id":"50","line_132404_credit":"3669.95","line_132404_debit":"0.00","line_132404_name":"Pago de cliente $\\u00a03,669.95 - 02/03/2024","line_132404_partner_id":"False","name":"PT1-CC/2024/00112"}',
#   'invoice_line_ids': [132403, 132404],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-02',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_globally',
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 3669.9500000000003,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 3669.9500000000003,
#   'amount_total_in_currency_signed': 3669.9500000000003,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'TRES MIL SEISCIENTOS SESENTA Y NUEVE PESOS 95/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Rosa Brenda Avilez Ceseña',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [502],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-03-02 13:35:38',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [1, 'Sales'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 501,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [100417],
#   'message_partner_ids': [16357],
#   'message_ids': [191847],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [35483,
#    'PT1-CC/2024/00111 (Combine Tarjeta Débito A1 pagos de PdV de [...])'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [49, 'Manual'],
#   'available_payment_method_line_ids': [49],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 7103.86,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': False,
#   'outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [50, '105.01.02 Clientes nacionales (PdV)'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [],
#   'reconciled_invoices_count': 0,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': True,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 7103.860000000001,
#   'amount_company_currency_signed': 7103.86,
#   'display_name': 'PT1-CC/2024/00111',
#   'create_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'create_date': '2024-03-02 20:35:37',
#   'write_uid': [237, 'Rosa Brenda Avilez Ceseña'],
#   'write_date': '2024-03-02 20:35:37',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': [29, 'Tarjeta Débito A1'],
#   'force_outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'pos_session_id': [117, 'POS/00117'],
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PT1-CC/2024/',
#   'sequence_number': 111,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PT1-CC/2024/00111',
#   'ref': 'Combine Tarjeta Débito A1 pagos de PdV de POS/00117',
#   'date': '2024-03-02',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [99, 'Tarjeta Deb/Cré A1'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [132400, 132401],
#   'payment_id': [501, 'PT1-CC/2024/00111'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PT1-CC/2024/00113',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-03-02","journal_id":"99","line_132400_account_id":"98","line_132400_credit":"0.00","line_132400_debit":"7103.86","line_132400_name":"Pago de cliente $\\u00a07,103.86 - 02/03/2024","line_132400_partner_id":"False","line_132401_account_id":"50","line_132401_credit":"7103.86","line_132401_debit":"0.00","line_132401_name":"Pago de cliente $\\u00a07,103.86 - 02/03/2024","line_132401_partner_id":"False","name":"PT1-CC/2024/00111"}',
#   'invoice_line_ids': [132400, 132401],
#   'invoice_date': False,
#   'invoice_date_due': '2024-03-02',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_globally',
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 7103.860000000001,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 7103.860000000001,
#   'amount_total_in_currency_signed': 7103.860000000001,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'SIETE MIL CIENTO TRES PESOS 86/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Rosa Brenda Avilez Ceseña',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [501],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-03-02 13:35:37',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [1, 'Sales'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 515,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [100877],
#   'message_partner_ids': [223],
#   'message_ids': [192683],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
# ...
#   'sequence_number': 103,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PBS1CC/2024/00103',
#   'ref': 'Combine Transferencia Banco Sant92000702524 pagos de PdV de POS/00107',
#   'date': '2024-02-26',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [15, 'Banco Sant92000702524'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [116787, 116788],
#   'payment_id': [402, 'PBS1CC/2024/00103'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PBS1CC/2024/00115',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-02-26","journal_id":"15","line_116787_account_id":"98","line_116787_credit":"0.00","line_116787_debit":"1916.34","line_116787_name":"Pago de cliente $\\u00a01,916.34 - 26/02/2024","line_116787_partner_id":"False","line_116788_account_id":"50","line_116788_credit":"1916.34","line_116788_debit":"0.00","line_116788_name":"Pago de cliente $\\u00a01,916.34 - 26/02/2024","line_116788_partner_id":"False","name":"PBS1CC/2024/00103"}',
#   'invoice_line_ids': [116787, 116788],
#   'invoice_date': False,
#   'invoice_date_due': '2024-02-26',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_globally',
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 1916.3400000000001,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 1916.3400000000001,
#   'amount_total_in_currency_signed': 1916.3400000000001,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'MIL NOVECIENTOS DIECISEIS PESOS 34/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Gladiz Melisa Galvez Espinoza',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [402],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-02-26 17:57:16',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [5, 'A1 CSL'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False},
#  {'id': 403,
#   'activity_ids': [],
#   'activity_state': False,
#   'activity_user_id': False,
#   'activity_type_id': False,
#   'activity_type_icon': False,
#   'activity_date_deadline': False,
#   'my_activity_date_deadline': False,
#   'activity_summary': False,
#   'activity_exception_decoration': False,
#   'activity_exception_icon': False,
#   'activity_calendar_event_id': False,
#   'message_is_follower': False,
#   'message_follower_ids': [90471],
#   'message_partner_ids': [219],
#   'message_ids': [173206],
#   'has_message': True,
#   'message_needaction': False,
#   'message_needaction_counter': 0,
#   'message_has_error': False,
#   'message_has_error_counter': 0,
#   'message_attachment_count': 0,
#   'rating_ids': [],
#   'website_message_ids': [],
#   'message_has_sms_error': False,
#   'message_main_attachment_id': False,
#   'move_id': [31635,
#    'PBB1CC/2024/00005 (Combine Transferencia Banco Bana70103464895 [...])'],
#   'is_reconciled': True,
#   'is_matched': False,
#   'available_partner_bank_ids': [],
#   'partner_bank_id': False,
#   'is_internal_transfer': False,
#   'qr_code': False,
#   'paired_internal_transfer_payment_id': False,
#   'payment_method_line_id': [39, 'Manual'],
#   'available_payment_method_line_ids': [39],
#   'payment_method_id': [1, 'Manual'],
#   'available_journal_ids': [93, 94, 96, 95, 15, 99, 100, 16, 91],
#   'amount': 430.3,
#   'payment_type': 'inbound',
#   'partner_type': 'customer',
#   'payment_reference': False,
#   'currency_id': [32, 'MXN'],
#   'partner_id': False,
#   'outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'destination_account_id': [50, '105.01.02 Clientes nacionales (PdV)'],
#   'destination_journal_id': False,
#   'reconciled_invoice_ids': [],
#   'reconciled_invoices_count': 0,
#   'reconciled_invoices_type': 'invoice',
#   'reconciled_bill_ids': [],
#   'reconciled_bills_count': 0,
#   'reconciled_statement_line_ids': [],
#   'reconciled_statement_lines_count': 0,
#   'payment_method_code': 'manual',
#   'show_partner_bank_account': True,
#   'require_partner_bank_account': False,
#   'country_code': 'MX',
#   'amount_signed': 430.3,
#   'amount_company_currency_signed': 430.3,
#   'display_name': 'PBB1CC/2024/00005',
#   'create_uid': [218, 'Gladiz Melisa Galvez Espinoza'],
#   'create_date': '2024-02-27 00:57:15',
#   'write_uid': [218, 'Gladiz Melisa Galvez Espinoza'],
#   'write_date': '2024-02-27 00:57:15',
#   'payment_transaction_id': False,
#   'payment_token_id': False,
#   'amount_available_for_refund': 0.0,
#   'suitable_payment_token_ids': [],
#   'use_electronic_payment_method': False,
#   'source_payment_id': False,
#   'refunds_count': 0,
#   'pos_payment_method_id': [33, 'Transferencia Banco Bana70103464895'],
#   'force_outstanding_account_id': [98, '102.01.71 Recibos pendientes'],
#   'pos_session_id': [107, 'POS/00107'],
#   'is_donation': False,
#   'pos_order_id': False,
#   'campaign_id': False,
#   'source_id': False,
#   'medium_id': False,
#   'sequence_prefix': 'PBB1CC/2024/',
#   'sequence_number': 5,
#   'access_url': '#',
#   'access_token': False,
#   'access_warning': '',
#   'name': 'PBB1CC/2024/00005',
#   'ref': 'Combine Transferencia Banco Bana70103464895 pagos de PdV de POS/00107',
#   'date': '2024-02-26',
#   'state': 'posted',
#   'move_type': 'entry',
#   'is_storno': False,
#   'journal_id': [93, 'Banco Bana70103464895'],
#   'company_id': [1, 'La Casa Del Carpintero De Los Cabos'],
#   'line_ids': [116790, 116791],
#   'payment_id': [403, 'PBB1CC/2024/00005'],
#   'statement_line_id': False,
#   'statement_id': False,
#   'tax_cash_basis_rec_id': False,
#   'tax_cash_basis_origin_move_id': False,
#   'tax_cash_basis_created_move_ids': [],
#   'always_tax_exigible': True,
#   'auto_post': 'no',
#   'auto_post_until': False,
#   'auto_post_origin_id': False,
#   'hide_post_button': True,
#   'to_check': False,
#   'posted_before': True,
#   'suitable_journal_ids': [12, 17, 13, 14, 18, 19, 92],
#   'highest_name': 'PBB1CC/2024/00004',
#   'made_sequence_hole': False,
#   'show_name_warning': False,
#   'type_name': 'Journal Entry',
#   'attachment_ids': [],
#   'restrict_mode_hash_table': False,
#   'secure_sequence_number': 0,
#   'inalterable_hash': False,
#   'string_to_hash': '{"company_id":"1","date":"2024-02-26","journal_id":"93","line_116790_account_id":"98","line_116790_credit":"0.00","line_116790_debit":"430.30","line_116790_name":"Pago de cliente $\\u00a0430.30 - 26/02/2024","line_116790_partner_id":"False","line_116791_account_id":"50","line_116791_credit":"430.30","line_116791_debit":"0.00","line_116791_name":"Pago de cliente $\\u00a0430.30 - 26/02/2024","line_116791_partner_id":"False","name":"PBB1CC/2024/00005"}',
#   'invoice_line_ids': [116790, 116791],
#   'invoice_date': False,
#   'invoice_date_due': '2024-02-26',
#   'delivery_date': False,
#   'show_delivery_date': False,
#   'invoice_payment_term_id': False,
#   'needed_terms': {},
#   'needed_terms_dirty': True,
#   'tax_calculation_rounding_method': 'round_globally',
#   'commercial_partner_id': False,
#   'partner_shipping_id': False,
#   'fiscal_position_id': False,
#   'display_qr_code': False,
#   'qr_code_method': False,
#   'invoice_outstanding_credits_debits_widget': False,
#   'invoice_has_outstanding': False,
#   'invoice_payments_widget': False,
#   'company_currency_id': [32, 'MXN'],
#   'direction_sign': 1,
#   'amount_untaxed': 0.0,
#   'amount_tax': 0.0,
#   'amount_total': 430.3,
#   'amount_residual': 0.0,
#   'amount_untaxed_signed': 0.0,
#   'amount_tax_signed': 0.0,
#   'amount_total_signed': 430.3,
#   'amount_total_in_currency_signed': 430.3,
#   'amount_residual_signed': 0.0,
#   'tax_totals': False,
#   'payment_state': 'not_paid',
#   'amount_total_words': 'CUATROCIENTOS TREINTA PESOS 30/100 M.N',
#   'reversed_entry_id': False,
#   'reversal_move_id': [],
#   'invoice_vendor_bill_id': False,
#   'invoice_source_email': False,
#   'invoice_partner_display_name': '#Creado por: Gladiz Melisa Galvez Espinoza',
#   'quick_edit_mode': False,
#   'quick_edit_total_amount': 0.0,
#   'quick_encoding_vals': False,
#   'narration': False,
#   'is_move_sent': False,
#   'is_being_sent': False,
#   'invoice_user_id': False,
#   'user_id': False,
#   'invoice_origin': False,
#   'invoice_incoterm_id': False,
#   'incoterm_location': False,
#   'invoice_cash_rounding_id': False,
#   'send_and_print_values': False,
#   'invoice_pdf_report_id': False,
#   'invoice_pdf_report_file': False,
#   'invoice_filter_type_domain': False,
#   'bank_partner_id': False,
#   'tax_lock_date_message': False,
#   'display_inactive_currency_warning': False,
#   'tax_country_id': [156, 'Mexico'],
#   'tax_country_code': 'MX',
#   'has_reconciled_entries': True,
#   'show_reset_to_draft_button': True,
#   'partner_credit_warning': '',
#   'partner_credit': 0.0,
#   'duplicated_ref_ids': [],
#   'need_cancel_request': False,
#   'payment_term_details': False,
#   'show_payment_term_details': False,
#   'show_discount_details': False,
#   'payment_ids': [403],
#   'statement_line_ids': [],
#   'payment_state_before_switch': False,
#   'deferred_move_ids': [],
#   'deferred_original_move_ids': [],
#   'deferred_entry_type': False,
#   'ubl_cii_xml_id': False,
#   'ubl_cii_xml_file': False,
#   'extract_state': 'no_extract_requested',
#   'extract_status': False,
#   'extract_error_message': 'An error occurred',
#   'extract_document_uuid': False,
#   'extract_can_show_send_button': False,
#   'is_in_extractable_state': False,
#   'extract_state_processed': False,
#   'extract_word_ids': [],
#   'extract_attachment_id': False,
#   'extract_can_show_banners': False,
#   'extract_detected_layout': 0,
#   'extract_partner_name': False,
#   'transaction_ids': [],
#   'authorized_transaction_ids': [],
#   'amount_paid': 0.0,
#   'purchase_vendor_bill_id': False,
#   'purchase_id': False,
#   'purchase_order_count': 0,
#   'stock_move_id': False,
#   'stock_valuation_layer_ids': [],
#   'transfer_model_id': False,
#   'tax_closing_end_date': False,
#   'tax_report_control_error': False,
#   'tax_closing_alert': False,
#   'tax_closing_show_multi_closing_warning': False,
#   'calendar_booking_ids': [],
#   'l10n_mx_edi_is_cfdi_needed': True,
#   'l10n_mx_edi_invoice_document_ids': [],
#   'l10n_mx_edi_payment_document_ids': [],
#   'l10n_mx_edi_document_ids': [],
#   'l10n_mx_edi_cfdi_state': False,
#   'l10n_mx_edi_cfdi_sat_state': False,
#   'l10n_mx_edi_cfdi_attachment_id': False,
#   'l10n_mx_edi_update_payments_needed': False,
#   'l10n_mx_edi_force_pue_payment_needed': False,
#   'l10n_mx_edi_update_sat_needed': False,
#   'l10n_mx_edi_post_time': '2024-02-26 17:57:16',
#   'l10n_mx_edi_usage': 'G03',
#   'l10n_mx_edi_cfdi_origin': False,
#   'l10n_mx_edi_invoice_cancellation_reason': False,
#   'l10n_mx_edi_cfdi_cancel_id': False,
#   'l10n_mx_edi_certificate_id': False,
#   'l10n_mx_edi_cer_source': False,
#   'l10n_mx_edi_cfdi_uuid': False,
#   'l10n_mx_edi_cfdi_supplier_rfc': False,
#   'l10n_mx_edi_cfdi_customer_rfc': False,
#   'l10n_mx_edi_cfdi_amount': 0.0,
#   'l10n_mx_edi_payment_method_id': [3, 'Transferencia electrónica de fondos'],
#   'l10n_mx_edi_payment_policy': False,
#   'l10n_mx_edi_cfdi_to_public': False,
#   'pos_order_ids': [],
#   'pos_payment_ids': [],
#   'pos_refunded_invoice_ids': [],
#   'team_id': [5, 'A1 CSL'],
#   'sale_order_count': 0,
#   'asset_id': False,
#   'asset_remaining_value': 0.0,
#   'asset_depreciated_value': 0.0,
#   'asset_value_change': False,
#   'asset_number_days': 0,
#   'asset_depreciation_beginning_date': False,
#   'depreciation_value': 0.0,
#   'asset_ids': [],
#   'asset_id_display_name': 'Activo',
#   'count_asset': 0,
#   'draft_asset_exists': False,
#   'impacting_cash_basis': False,
#   'suspense_statement_line_id': False,
#   'l10n_mx_closing_move': False,
#   'x_customer_purchase_order': False}]
