# %%
import xmlrpc.client
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
api_url = os.environ.get('ODOO_URL_API')
api_db = os.environ.get('ODOO_DB_API')
api_username = os.environ.get('ODOO_USERNAME_API')
api_clave = os.environ.get('ODOO_CLAVE_API')

# %%
# Verificar que la conexión es correcta

common = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/common')
common.version()
# Out:
# {'server_version': '17.0+e',
#  'server_version_info': [17, 0, 0, 'final', 0, 'e'],
#  'server_serie': '17.0',
#  'protocol_version': 1}

# %%
# Función para autenticar al usuario_API

uid = common.authenticate(api_db, api_username, api_clave, {})
uid
# Out:
# 239

# %%
# Función para invocar el objeto models

models = xmlrpc.client.ServerProxy(f'{api_url}/xmlrpc/2/object')

# %%
# Función para checar si el usuario tiene permisos de acceso al modelo en cuestión

models.execute_kw(api_db, uid, api_clave, 'res.partner', 'check_access_rights', ['read'], {'raise_exception': False})
# Out:
# True

# %%
fields = ['partner_id', 'name', 'email', 'create_date', 'state']
response = models.execute_kw(api_db, uid, api_clave, 'res.users', 'search_read', [], {'fields': fields})

# %%
response
# Out:
# [{'id': 239,
#   'partner_id': [16604, 'API'],
#   'name': 'API',
#   'email': 'api@ccc.com',
#   'create_date': '2024-02-28 05:55:01',
#   'state': 'active'},
#  {'id': 240,
#   'partner_id': [16606, 'Alexa Yadira Mazariegos Zunun'],
#   'name': 'Alexa Yadira Mazariegos Zunun',
#   'email': 'alexamz@ccc.com',
#   'create_date': '2024-02-28 18:43:10',
#   'state': 'active'},
#  {'id': 233,
#   'partner_id': [234, 'Angela Carrillo Cárdenas'],
#   'name': 'Angela Carrillo Cárdenas',
#   'email': 'angelacc@ccc.com',
#   'create_date': '2023-12-26 18:04:53',
#   'state': 'active'},
#  {'id': 236,
#   'partner_id': [237, 'Bianca Sánchez Valenciano'],
#   'name': 'Bianca Sánchez Valenciano',
#   'email': 'biancasv@ccc.com',
#   'create_date': '2023-12-26 18:04:53',
#   'state': 'active'},
#  {'id': 205,
#   'partner_id': [206, 'Brenda Luz Acosta Lopez'],
#   'name': 'Brenda Luz Acosta Lopez',
#   'email': 'brendaal@ccc.com',
#   'create_date': '2023-12-26 18:04:53',
# ...

# %%
len(response)
# Out:
# 31

# %%
for e in response:
    print(e['id'])
    print(e['name'])
    print(e['email'])
    print('\n')
# Out:
# 239
# API
# api@ccc.com
#
#
# 240
# Alexa Yadira Mazariegos Zunun
# alexamz@ccc.com
#
#
# 233
# Angela Carrillo Cárdenas
# angelacc@ccc.com
#
#
# 236
# Bianca Sánchez Valenciano
# biancasv@ccc.com
#
#
# 205
# Brenda Luz Acosta Lopez
# brendaal@ccc.com
#
#
# 232
# Carlos Humberto Briones Contreras
# carlosbc@ccc.com
#
#
# 208
# Carlos Manuel Guzmán Rios
# carlosgr@ccc.com
#
#
# 241
# Dulce Guadalupe Pedroza Valenzuela
# dulcepv@ccc.com
#
#
# 207
# Elsa Ivette Diaz Leyva
# elsadl@ccc.com
#
#
# 218
# Gladiz Melisa Galvez Espinoza
# gladizge@ccc.com
#
#
# 215
# Gretel Gómez Alcázar
# gretelga@ccc.com
#
#
# 210
# Irma Carvajal Flores
# irmacf@ccc.com
#
#
# 238
# Karely Guadalupe Green Ceseña
# karelyggc@ccc.com
#
#
# 221
# Karla Jaqueline Rivera Hernández
# karlarh@ccc.com
#
#
# 224
# Leticia Terán Salinas
# leticiats@ccc.com
#
#
# 2
# Lic. Costich
# emilio@lacasadelcarpintero.mx
#
#
# 206
# Mariana Araceli Carvajal Flores
# marianacf@ccc.com
#
#
# 211
# Mayra Angelica Parada Manjarrez
# ...

# %%
df = pd.DataFrame(response)
df
# Out:
#      id                                   partner_id  \
# 0   239                                 [16604, API]
# 1   240       [16606, Alexa Yadira Mazariegos Zunun]
# 2   233              [234, Angela Carrillo Cárdenas]
# 3   236             [237, Bianca Sánchez Valenciano]
# 4   205               [206, Brenda Luz Acosta Lopez]
# 5   232     [233, Carlos Humberto Briones Contreras]
# 6   208             [209, Carlos Manuel Guzmán Rios]
# 7   241  [16607, Dulce Guadalupe Pedroza Valenzuela]
# 8   207                [208, Elsa Ivette Diaz Leyva]
# 9   218         [219, Gladiz Melisa Galvez Espinoza]
# 10  215                  [216, Gretel Gómez Alcázar]
# 11  210                  [211, Irma Carvajal Flores]
# 12  238       [16533, Karely Guadalupe Green Ceseña]
# 13  221      [222, Karla Jaqueline Rivera Hernández]
# 14  224                 [225, Leticia Terán Salinas]
# 15    2                            [3, Lic. Costich]
# 16  206       [207, Mariana Araceli Carvajal Flores]
# ...

# %%
df[['name', 'email']]
# Out:
#                                     name                            email
# 0                                    API                      api@ccc.com
# 1          Alexa Yadira Mazariegos Zunun                  alexamz@ccc.com
# 2               Angela Carrillo Cárdenas                 angelacc@ccc.com
# 3              Bianca Sánchez Valenciano                 biancasv@ccc.com
# 4                Brenda Luz Acosta Lopez                 brendaal@ccc.com
# 5      Carlos Humberto Briones Contreras                 carlosbc@ccc.com
# 6              Carlos Manuel Guzmán Rios                 carlosgr@ccc.com
# 7     Dulce Guadalupe Pedroza Valenzuela                  dulcepv@ccc.com
# 8                 Elsa Ivette Diaz Leyva                   elsadl@ccc.com
# 9          Gladiz Melisa Galvez Espinoza                 gladizge@ccc.com
# 10                  Gretel Gómez Alcázar                 gretelga@ccc.com
# 11                  Irma Carvajal Flores                   irmacf@ccc.com
# ...
